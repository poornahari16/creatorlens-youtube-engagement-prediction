# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/raw/youtube_dataset.csv")

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  r3I1_biJ5Rs  How OpenAI technology 'went rogue' | Global Ne...
# 1  rIj7DnrshxY  Tech News 2212 || Galaxy Unpacked, vivo S2, re...
# 2  pKsEFQgpe-o  Nvidia Rolls Out New Chips, WBD Deal In Limbo ...
# 3  qnnXBakpLoc  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...
# 4  2JgJ1MRhntg  Microsoft in the race to build the ultimate su...
#
#                                          description          published_at  \
# 0  The artificial intelligence giant OpenAI - mak...  2006-04-08T05:51:05Z
# 1  Tech News 2212 || Galaxy Unpacked, vivo S2, re...  2015-11-12T05:14:19Z
# 2  Bloomberg's Ed Ludlow breaks down Nvidia's lat...  2016-09-01T21:38:32Z
# 3  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...  2015-11-12T05:14:19Z
# 4  Computing giant Microsoft has spent 20 years p...  2006-04-08T05:51:05Z
#
#                  channel_id       channel_title  category_id  \
# 0  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
# 1  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 2  UCrM7B7SL_g1edFOnmj-SDKg      Bloomberg Tech           25
# 3  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 4  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
#
#                                                 tags duration  view_count  \
# 0  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT9M43S  7128283600
# 1  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M47S  2188859182
# 2  ['Advisors Capital Management LLC', 'Bessemer ...  PT49M8S   177869185
# 3  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M18S  2188859182
# 4  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT5M33S  7128283600
#
#    like_count  comment_count  \
# 0       338.0          140.0
# 1      8255.0          304.0
# 2       139.0            8.0
# 3      9297.0          265.0
# 4      2212.0          341.0
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# 1  https://i.ytimg.com/vi/rIj7DnrshxY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/pKsEFQgpe-o/hqdefault.jpg
# 3  https://i.ytimg.com/vi/qnnXBakpLoc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/2JgJ1MRhntg/hqdefault.jpg
#
#                                  channel_description country  \
# 0  Breaking news, live updates and in-depth analy...      GB
# 1  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 2  Welcome to the Bloomberg Tech YouTube channel....     NaN
# 3  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 4  Breaking news, live updates and in-depth analy...      GB
#
#    subscriber_count  video_count   search_keyword search_category  \
# 0          19900000        31890  technology news      Technology
# 1           5140000         5351  technology news      Technology
# 2            732000        13916  technology news      Technology
# 3           5140000         5351  technology news      Technology
# 4          19900000        31890  technology news      Technology
#
#           collected_at
# 0  2026-07-23 13:24:57
# 5277  2026-08-14 17:30:33
# 5278  2026-08-14 17:30:33
# 5279  2026-08-14 17:30:33

# %%
df.shape
# Out:
# (5280, 20)

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_id',
#        'channel_title', 'category_id', 'tags', 'duration', 'view_count',
#        'like_count', 'comment_count', 'thumbnail_url', 'channel_description',
#        'country', 'subscriber_count', 'video_count', 'search_keyword',
#        'search_category', 'collected_at'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5280 entries, 0 to 5279
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             5280 non-null   str
#  1   title                5280 non-null   str
#  2   description          4510 non-null   str
#  3   published_at         5280 non-null   str
#  4   channel_id           5280 non-null   str
#  5   channel_title        5280 non-null   str
#  6   category_id          5280 non-null   int64
#  7   tags                 3649 non-null   str
#  8   duration             5280 non-null   str
#  9   view_count           5280 non-null   int64
#  10  like_count           5102 non-null   float64
#  11  comment_count        5240 non-null   float64
#  12  thumbnail_url        5280 non-null   str
#  13  channel_description  5092 non-null   str
#  14  country              4577 non-null   str
#  15  subscriber_count     5280 non-null   int64
#  16  video_count          5280 non-null   int64
#  17  search_keyword       5280 non-null   str
#  18  search_category      5280 non-null   str
#  19  collected_at         5280 non-null   str
# dtypes: float64(2), int64(4), str(14)
# memory usage: 12.9 MB

# %%
df.isnull().sum()
# Out:
# video_id                  0
# title                     0
# description             770
# published_at              0
# channel_id                0
# channel_title             0
# category_id               0
# tags                   1631
# duration                  0
# view_count                0
# like_count              178
# comment_count            40
# thumbnail_url             0
# channel_description     188
# country                 703
# subscriber_count          0
# video_count               0
# search_keyword            0
# search_category           0
# collected_at              0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# video_id                0.000000
# title                   0.000000
# description            14.583333
# published_at            0.000000
# channel_id              0.000000
# channel_title           0.000000
# category_id             0.000000
# tags                   30.890152
# duration                0.000000
# view_count              0.000000
# like_count              3.371212
# comment_count           0.757576
# thumbnail_url           0.000000
# channel_description     3.560606
# country                13.314394
# subscriber_count        0.000000
# video_count             0.000000
# search_keyword          0.000000
# search_category         0.000000
# collected_at            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# video_id 5280
# title 5183
# description 4424
# published_at 3220
# channel_id 3220
# channel_title 3219
# category_id 15
# tags 3395
# duration 2092
# view_count 4037
# like_count 4296
# comment_count 1623
# thumbnail_url 5280
# channel_description 3074
# country 63
# subscriber_count 2097
# video_count 1963
# search_keyword 131
# search_category 27
# collected_at 698

# %%
df.describe(include="all")
# Out:
#            video_id                                              title  \
# count          5280                                               5280
# unique         5280                                               5183
# top     r3I1_biJ5Rs  Tom Holland React Viral Videos #tomholland #fu...
# freq              1                                                 14
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                                               description  \
# count                                                4510
# unique                                               4424
# top     🔥GIVEAWAY🔥\nhttps://www.instagram.com/thegamet...
# freq                                                   17
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                 published_at                channel_id channel_title  \
# count                   5280                      5280          5280
# unique                  3220                      3220          3219
# top     2009-10-29T07:21:23Z  UCsvqVGtbbyHaMoevxPAq9Fg   Simplilearn
# freq                      70                        70            70
# mean                     NaN                       NaN           NaN
# std                      NaN                       NaN           NaN
# min                      NaN                       NaN           NaN
# 25%                      NaN                       NaN           NaN
# 50%                      NaN                       NaN           NaN
# 75%                      NaN                       NaN           NaN
# max                      NaN                       NaN           NaN
#
#         category_id                                               tags  \
# count   5280.000000                                               3649
# unique          NaN                                               3395
# top             NaN  ['C++', 'C++ coding', 'C++ full course', 'C++ ...
# freq            NaN                                                 19
# mean      24.767803                                                NaN
# std        4.245884                                                NaN
# min        1.000000                                                NaN
# 25%       22.000000                                                NaN
# 50%       27.000000                                                NaN
# 75%       27.000000                                                NaN
# max       29.000000                                                NaN
#
#        duration    view_count    like_count  comment_count  \
# count      5280  5.280000e+03  5.102000e+03    5240.000000
# unique     2092           NaN           NaN            NaN
# top        PT1M           NaN           NaN            NaN
# freq        126           NaN           NaN            NaN
# mean        NaN  9.767728e+08  7.674215e+04    1162.652863
# std         NaN  6.326558e+09  3.581228e+05    7789.183298
# min         NaN  2.746000e+03  0.000000e+00       0.000000
# 25%         NaN  1.289286e+07  1.036500e+03      29.000000
# 50%         NaN  8.297291e+07  7.005000e+03     147.500000
# 75%         NaN  4.696810e+08  3.530175e+04     587.250000
# max         NaN  3.493701e+11  1.371858e+07  412557.000000
#
#                                            thumbnail_url  \
# count                                               5280
# unique                                              5280
# top     https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                       channel_description country  \
# count                                                5092    4577
# unique                                               3074      63
# top     Simplilearn is the world’s leading online trai...      IN
# freq                                                   70    2190
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#         subscriber_count    video_count       search_keyword search_category  \
# count       5.280000e+03    5280.000000                 5280            5280
# unique               NaN            NaN                  131              27
# top                  NaN            NaN  consumer technology      Technology
# freq                 NaN            NaN                  182             551
# mean        2.846579e+06    5536.741477                  NaN             NaN
# std         1.389796e+07   32634.935641                  NaN             NaN
# min         1.100000e+01       1.000000                  NaN             NaN
# 25%         6.877500e+04     255.000000                  NaN             NaN
# 50%         4.455000e+05     729.000000                  NaN             NaN
# 75%         2.150000e+06    1738.750000                  NaN             NaN
# max         5.120000e+08  720681.000000                  NaN             NaN
#
#                collected_at
# count                  5280
# unique                  698
# top     2026-07-23 13:24:57
# freq                     20
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
print(df.columns.tolist())
# Out:
# ['video_id', 'title', 'description', 'published_at', 'channel_id', 'channel_title', 'category_id', 'tags', 'duration', 'view_count', 'like_count', 'comment_count', 'thumbnail_url', 'channel_description', 'country', 'subscriber_count', 'video_count', 'search_keyword', 'search_category', 'collected_at']

# %% [markdown]
# **Negative Values**

# %%
numeric_cols = [
    "view_count",
    "like_count",
    "comment_count",
    "subscriber_count",
]

(df[numeric_cols] < 0).sum()
# Out:
# view_count          0
# like_count          0
# comment_count       0
# subscriber_count    0
# dtype: int64

# %% [markdown]
# Zero Values

# %%
(df[numeric_cols] == 0).sum()
# Out:
# view_count            0
# like_count            3
# comment_count       229
# subscriber_count      0
# dtype: int64
