# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/raw/youtube_dataset.csv")

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  r3I1_biJ5Rs  How OpenAI technology 'went rogue' | Global Ne...
# 1  rIj7DnrshxY  Tech News 2212 || Galaxy Unpacked, vivo S2, re...
# 2  pKsEFQgpe-o  Nvidia Rolls Out New Chips, WBD Deal In Limbo ...
# 3  qnnXBakpLoc  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...
# 4  2JgJ1MRhntg  Microsoft in the race to build the ultimate su...
#
#                                          description          published_at  \
# 0  The artificial intelligence giant OpenAI - mak...  2006-04-08T05:51:05Z
# 1  Tech News 2212 || Galaxy Unpacked, vivo S2, re...  2015-11-12T05:14:19Z
# 2  Bloomberg's Ed Ludlow breaks down Nvidia's lat...  2016-09-01T21:38:32Z
# 3  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...  2015-11-12T05:14:19Z
# 4  Computing giant Microsoft has spent 20 years p...  2006-04-08T05:51:05Z
#
#                  channel_id       channel_title  category_id  \
# 0  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
# 1  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 2  UCrM7B7SL_g1edFOnmj-SDKg      Bloomberg Tech           25
# 3  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 4  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
#
#                                                 tags duration  view_count  \
# 0  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT9M43S  7128283600
# 1  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M47S  2188859182
# 2  ['Advisors Capital Management LLC', 'Bessemer ...  PT49M8S   177869185
# 3  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M18S  2188859182
# 4  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT5M33S  7128283600
#
#    like_count  comment_count  \
# 0       338.0          140.0
# 1      8255.0          304.0
# 2       139.0            8.0
# 3      9297.0          265.0
# 4      2212.0          341.0
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# 1  https://i.ytimg.com/vi/rIj7DnrshxY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/pKsEFQgpe-o/hqdefault.jpg
# 3  https://i.ytimg.com/vi/qnnXBakpLoc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/2JgJ1MRhntg/hqdefault.jpg
#
#                                  channel_description country  \
# 0  Breaking news, live updates and in-depth analy...      GB
# 1  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 2  Welcome to the Bloomberg Tech YouTube channel....     NaN
# 3  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 4  Breaking news, live updates and in-depth analy...      GB
#
#    subscriber_count  video_count   search_keyword search_category  \
# 0          19900000        31890  technology news      Technology
# 1           5140000         5351  technology news      Technology
# 2            732000        13916  technology news      Technology
# 3           5140000         5351  technology news      Technology
# 4          19900000        31890  technology news      Technology
#
#           collected_at
# 0  2026-07-23 13:24:57
# 2226  2026-07-24 17:19:40
# 2227  2026-07-24 17:19:40
# 2228  2026-07-24 17:19:40

# %%
df.shape
# Out:
# (2229, 20)

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_id',
#        'channel_title', 'category_id', 'tags', 'duration', 'view_count',
#        'like_count', 'comment_count', 'thumbnail_url', 'channel_description',
#        'country', 'subscriber_count', 'video_count', 'search_keyword',
#        'search_category', 'collected_at'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2229 entries, 0 to 2228
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             2229 non-null   str
#  1   title                2229 non-null   str
#  2   description          1990 non-null   str
#  3   published_at         2229 non-null   str
#  4   channel_id           2229 non-null   str
#  5   channel_title        2229 non-null   str
#  6   category_id          2229 non-null   int64
#  7   tags                 1663 non-null   str
#  8   duration             2229 non-null   str
#  9   view_count           2229 non-null   int64
#  10  like_count           2158 non-null   float64
#  11  comment_count        2209 non-null   float64
#  12  thumbnail_url        2229 non-null   str
#  13  channel_description  2189 non-null   str
#  14  country              1972 non-null   str
#  15  subscriber_count     2229 non-null   int64
#  16  video_count          2229 non-null   int64
#  17  search_keyword       2229 non-null   str
#  18  search_category      2229 non-null   str
#  19  collected_at         2229 non-null   str
# dtypes: float64(2), int64(4), str(14)
# memory usage: 5.8 MB

# %%
df.isnull().sum()
# Out:
# video_id                 0
# title                    0
# description            239
# published_at             0
# channel_id               0
# channel_title            0
# category_id              0
# tags                   566
# duration                 0
# view_count               0
# like_count              71
# comment_count           20
# thumbnail_url            0
# channel_description     40
# country                257
# subscriber_count         0
# video_count              0
# search_keyword           0
# search_category          0
# collected_at             0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# video_id                0.000000
# title                   0.000000
# description            10.722297
# published_at            0.000000
# channel_id              0.000000
# channel_title           0.000000
# category_id             0.000000
# tags                   25.392553
# duration                0.000000
# view_count              0.000000
# like_count              3.185285
# comment_count           0.897263
# thumbnail_url           0.000000
# channel_description     1.794527
# country                11.529834
# subscriber_count        0.000000
# video_count             0.000000
# search_keyword          0.000000
# search_category         0.000000
# collected_at            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# video_id 2229
# title 2218
# description 1964
# published_at 1423
# channel_id 1423
# channel_title 1423
# category_id 13
# tags 1581
# duration 1170
# view_count 1442
# like_count 2048
# comment_count 1056
# thumbnail_url 2229
# channel_description 1381
# country 45
# subscriber_count 1091
# video_count 999
# search_keyword 116
# search_category 14
# collected_at 116

# %%
df.describe(include="all")
# Out:
#            video_id                                              title  \
# count          2229                                               2229
# unique         2229                                               2218
# top     r3I1_biJ5Rs  🔥Top Best Useful Gadgets In The World | Amazon...
# freq              1                                                  2
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                                               description  \
# count                                                1990
# unique                                               1964
# top     *TELEGRAM LINK 📌* \nhttps://t.me/Shivani_Palle...
# freq                                                    7
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                 published_at                channel_id channel_title  \
# count                   2229                      2229          2229
# unique                  1423                      1423          1423
# top     2009-10-29T07:21:23Z  UCsvqVGtbbyHaMoevxPAq9Fg   Simplilearn
# freq                      40                        40            40
# mean                     NaN                       NaN           NaN
# std                      NaN                       NaN           NaN
# min                      NaN                       NaN           NaN
# 25%                      NaN                       NaN           NaN
# 50%                      NaN                       NaN           NaN
# 75%                      NaN                       NaN           NaN
# max                      NaN                       NaN           NaN
#
#         category_id                                               tags  \
# count   2229.000000                                               1663
# unique          NaN                                               1581
# top             NaN  ['warikoo', 'ankur warikoo', 'Ankur Warikoo mo...
# freq            NaN                                                  8
# mean      25.598923                                                NaN
# std        3.475578                                                NaN
# min        1.000000                                                NaN
# 25%       24.000000                                                NaN
# 50%       27.000000                                                NaN
# 75%       27.000000                                                NaN
# max       29.000000                                                NaN
#
#        duration    view_count    like_count  comment_count  \
# count      2229  2.229000e+03  2.158000e+03    2209.000000
# unique     1170           NaN           NaN            NaN
# top        PT1M           NaN           NaN            NaN
# freq         55           NaN           NaN            NaN
# mean        NaN  8.810023e+08  7.543361e+04    1575.276596
# std         NaN  3.983418e+09  2.872278e+05   11010.302601
# min         NaN  3.600000e+03  1.000000e+00       0.000000
# 25%         NaN  1.394165e+07  2.390500e+03      50.000000
# 50%         NaN  8.542475e+07  1.064850e+04     222.000000
# 75%         NaN  4.691659e+08  4.483800e+04     794.000000
# max         NaN  1.342652e+11  6.215914e+06  412557.000000
#
#                                            thumbnail_url  \
# count                                               2229
# unique                                              2229
# top     https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                       channel_description country  \
# count                                                2189    1972
# unique                                               1381      45
# top     Simplilearn is the world’s leading online trai...      IN
# freq                                                   40     932
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#         subscriber_count    video_count   search_keyword    search_category  \
# count       2.229000e+03    2229.000000             2229               2229
# unique               NaN            NaN              116                 14
# top                  NaN            NaN  technology news  Digital Marketing
# freq                 NaN            NaN               20                199
# mean        3.131547e+06    5531.970390              NaN                NaN
# std         1.219601e+07   31666.481148              NaN                NaN
# min         2.200000e+01       1.000000              NaN                NaN
# 25%         8.680000e+04     257.000000              NaN                NaN
# 50%         6.300000e+05     764.000000              NaN                NaN
# 75%         2.820000e+06    1956.000000              NaN                NaN
# max         5.090000e+08  665951.000000              NaN                NaN
#
#                collected_at
# count                  2229
# unique                  116
# top     2026-07-23 13:24:57
# freq                     20
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
print(df.columns.tolist())
# Out:
# ['video_id', 'title', 'description', 'published_at', 'channel_id', 'channel_title', 'category_id', 'tags', 'duration', 'view_count', 'like_count', 'comment_count', 'thumbnail_url', 'channel_description', 'country', 'subscriber_count', 'video_count', 'search_keyword', 'search_category', 'collected_at']

# %% [markdown]
# **Negative Values**

# %%
numeric_cols = [
    "view_count",
    "like_count",
    "comment_count",
    "subscriber_count",
]

(df[numeric_cols] < 0).sum()
# Out:
# view_count          0
# like_count          0
# comment_count       0
# subscriber_count    0
# dtype: int64

# %% [markdown]
# Zero Values

# %%
(df[numeric_cols] == 0).sum()
# Out:
# view_count           0
# like_count           0
# comment_count       46
# subscriber_count     0
# dtype: int64
