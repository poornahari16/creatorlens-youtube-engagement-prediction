# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/raw/youtube_dataset.csv")

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  r3I1_biJ5Rs  How OpenAI technology 'went rogue' | Global Ne...
# 1  rIj7DnrshxY  Tech News 2212 || Galaxy Unpacked, vivo S2, re...
# 2  pKsEFQgpe-o  Nvidia Rolls Out New Chips, WBD Deal In Limbo ...
# 3  qnnXBakpLoc  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...
# 4  2JgJ1MRhntg  Microsoft in the race to build the ultimate su...
#
#                                          description          published_at  \
# 0  The artificial intelligence giant OpenAI - mak...  2006-04-08T05:51:05Z
# 1  Tech News 2212 || Galaxy Unpacked, vivo S2, re...  2015-11-12T05:14:19Z
# 2  Bloomberg's Ed Ludlow breaks down Nvidia's lat...  2016-09-01T21:38:32Z
# 3  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...  2015-11-12T05:14:19Z
# 4  Computing giant Microsoft has spent 20 years p...  2006-04-08T05:51:05Z
#
#                  channel_id       channel_title  category_id  \
# 0  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
# 1  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 2  UCrM7B7SL_g1edFOnmj-SDKg      Bloomberg Tech           25
# 3  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 4  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
#
#                                                 tags duration  view_count  \
# 0  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT9M43S  7128283600
# 1  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M47S  2188859182
# 2  ['Advisors Capital Management LLC', 'Bessemer ...  PT49M8S   177869185
# 3  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M18S  2188859182
# 4  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT5M33S  7128283600
#
#    like_count  comment_count  \
# 0       338.0          140.0
# 1      8255.0          304.0
# 2       139.0            8.0
# 3      9297.0          265.0
# 4      2212.0          341.0
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# 1  https://i.ytimg.com/vi/rIj7DnrshxY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/pKsEFQgpe-o/hqdefault.jpg
# 3  https://i.ytimg.com/vi/qnnXBakpLoc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/2JgJ1MRhntg/hqdefault.jpg
#
#                                  channel_description country  \
# 0  Breaking news, live updates and in-depth analy...      GB
# 1  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 2  Welcome to the Bloomberg Tech YouTube channel....     NaN
# 3  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 4  Breaking news, live updates and in-depth analy...      GB
#
#    subscriber_count  video_count   search_keyword search_category  \
# 0          19900000        31890  technology news      Technology
# 1           5140000         5351  technology news      Technology
# 2            732000        13916  technology news      Technology
# 3           5140000         5351  technology news      Technology
# 4          19900000        31890  technology news      Technology
#
#           collected_at
# 0  2026-07-23 13:24:57
# 1  2026-07-23 13:24:57
# 4866  Digital Marketing  2026-08-13 18:46:41
# 4867  Digital Marketing  2026-08-13 18:46:41
# 4868  Digital Marketing  2026-08-13 18:46:41
# 4869  Digital Marketing  2026-08-13 18:46:41

# %%
df.shape
# Out:
# (4870, 20)

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_id',
#        'channel_title', 'category_id', 'tags', 'duration', 'view_count',
#        'like_count', 'comment_count', 'thumbnail_url', 'channel_description',
#        'country', 'subscriber_count', 'video_count', 'search_keyword',
#        'search_category', 'collected_at'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4870 entries, 0 to 4869
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             4870 non-null   str
#  1   title                4870 non-null   str
#  2   description          4141 non-null   str
#  3   published_at         4870 non-null   str
#  4   channel_id           4870 non-null   str
#  5   channel_title        4870 non-null   str
#  6   category_id          4870 non-null   int64
#  7   tags                 3343 non-null   str
#  8   duration             4870 non-null   str
#  9   view_count           4870 non-null   int64
#  10  like_count           4708 non-null   float64
#  11  comment_count        4838 non-null   float64
#  12  thumbnail_url        4870 non-null   str
#  13  channel_description  4693 non-null   str
#  14  country              4205 non-null   str
#  15  subscriber_count     4870 non-null   int64
#  16  video_count          4870 non-null   int64
#  17  search_keyword       4870 non-null   str
#  18  search_category      4870 non-null   str
#  19  collected_at         4870 non-null   str
# dtypes: float64(2), int64(4), str(14)
# memory usage: 11.8 MB

# %%
df.isnull().sum()
# Out:
# video_id                  0
# title                     0
# description             729
# published_at              0
# channel_id                0
# channel_title             0
# category_id               0
# tags                   1527
# duration                  0
# view_count                0
# like_count              162
# comment_count            32
# thumbnail_url             0
# channel_description     177
# country                 665
# subscriber_count          0
# video_count               0
# search_keyword            0
# search_category           0
# collected_at              0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# video_id                0.000000
# title                   0.000000
# description            14.969199
# published_at            0.000000
# channel_id              0.000000
# channel_title           0.000000
# category_id             0.000000
# tags                   31.355236
# duration                0.000000
# view_count              0.000000
# like_count              3.326489
# comment_count           0.657084
# thumbnail_url           0.000000
# channel_description     3.634497
# country                13.655031
# subscriber_count        0.000000
# video_count             0.000000
# search_keyword          0.000000
# search_category         0.000000
# collected_at            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# video_id 4870
# title 4778
# description 4067
# published_at 3009
# channel_id 3009
# channel_title 3007
# category_id 15
# tags 3113
# duration 1965
# view_count 3691
# like_count 4025
# comment_count 1554
# thumbnail_url 4870
# channel_description 2867
# country 63
# subscriber_count 1985
# video_count 1856
# search_keyword 131
# search_category 27
# collected_at 618

# %%
df.describe(include="all")
# Out:
#            video_id                                              title  \
# count          4870                                               4870
# unique         4870                                               4778
# top     r3I1_biJ5Rs  Tom Holland React Viral Videos #tomholland #fu...
# freq              1                                                 14
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                                               description  \
# count                                                4141
# unique                                               4067
# top     🔥GIVEAWAY🔥\nhttps://www.instagram.com/thegamet...
# freq                                                   17
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                 published_at                channel_id channel_title  \
# count                   4870                      4870          4870
# unique                  3009                      3009          3007
# top     2009-10-29T07:21:23Z  UCsvqVGtbbyHaMoevxPAq9Fg   Simplilearn
# freq                      63                        63            63
# mean                     NaN                       NaN           NaN
# std                      NaN                       NaN           NaN
# min                      NaN                       NaN           NaN
# 25%                      NaN                       NaN           NaN
# 50%                      NaN                       NaN           NaN
# 75%                      NaN                       NaN           NaN
# max                      NaN                       NaN           NaN
#
#         category_id                                               tags  \
# count   4870.000000                                               3343
# unique          NaN                                               3113
# top             NaN  ['C++', 'C++ coding', 'C++ full course', 'C++ ...
# freq            NaN                                                 17
# mean      24.667762                                                NaN
# std        4.348460                                                NaN
# min        1.000000                                                NaN
# 25%       22.000000                                                NaN
# 50%       27.000000                                                NaN
# 75%       27.000000                                                NaN
# max       29.000000                                                NaN
#
#        duration    view_count    like_count  comment_count  \
# count      4870  4.870000e+03  4.708000e+03    4838.000000
# unique     1965           NaN           NaN            NaN
# top        PT1M           NaN           NaN            NaN
# freq        117           NaN           NaN            NaN
# mean        NaN  9.747901e+08  7.683551e+04    1173.498346
# std         NaN  6.515644e+09  3.601608e+05    8053.035828
# min         NaN  2.746000e+03  0.000000e+00       0.000000
# 25%         NaN  1.349726e+07  1.095750e+03      30.000000
# 50%         NaN  8.395756e+07  7.219000e+03     150.000000
# 75%         NaN  4.694911e+08  3.601225e+04     586.750000
# max         NaN  3.493701e+11  1.371858e+07  412557.000000
#
#                                            thumbnail_url  \
# count                                               4870
# unique                                              4870
# top     https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                       channel_description country  \
# count                                                4693    4205
# unique                                               2867      63
# top     Simplilearn is the world’s leading online trai...      IN
# freq                                                   63    2027
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#         subscriber_count    video_count       search_keyword search_category  \
# count       4.870000e+03    4870.000000                 4870            4870
# unique               NaN            NaN                  131              27
# top                  NaN            NaN  consumer technology      Technology
# freq                 NaN            NaN                  172             495
# mean        2.823484e+06    5304.915195                  NaN             NaN
# std         1.432249e+07   30897.740135                  NaN             NaN
# min         1.100000e+01       1.000000                  NaN             NaN
# 25%         6.832500e+04     250.000000                  NaN             NaN
# 50%         4.385000e+05     723.500000                  NaN             NaN
# 75%         2.100000e+06    1708.000000                  NaN             NaN
# max         5.120000e+08  672368.000000                  NaN             NaN
#
#                collected_at
# count                  4870
# unique                  618
# top     2026-07-23 13:24:57
# freq                     20
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
print(df.columns.tolist())
# Out:
# ['video_id', 'title', 'description', 'published_at', 'channel_id', 'channel_title', 'category_id', 'tags', 'duration', 'view_count', 'like_count', 'comment_count', 'thumbnail_url', 'channel_description', 'country', 'subscriber_count', 'video_count', 'search_keyword', 'search_category', 'collected_at']

# %% [markdown]
# **Negative Values**

# %%
numeric_cols = [
    "view_count",
    "like_count",
    "comment_count",
    "subscriber_count",
]

(df[numeric_cols] < 0).sum()
# Out:
# view_count          0
# like_count          0
# comment_count       0
# subscriber_count    0
# dtype: int64

# %% [markdown]
# Zero Values

# %%
(df[numeric_cols] == 0).sum()
# Out:
# view_count            0
# like_count            3
# comment_count       211
# subscriber_count      0
# dtype: int64
