# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/raw/youtube_dataset.csv")

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  r3I1_biJ5Rs  How OpenAI technology 'went rogue' | Global Ne...
# 1  rIj7DnrshxY  Tech News 2212 || Galaxy Unpacked, vivo S2, re...
# 2  pKsEFQgpe-o  Nvidia Rolls Out New Chips, WBD Deal In Limbo ...
# 3  qnnXBakpLoc  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...
# 4  2JgJ1MRhntg  Microsoft in the race to build the ultimate su...
#
#                                          description          published_at  \
# 0  The artificial intelligence giant OpenAI - mak...  2006-04-08T05:51:05Z
# 1  Tech News 2212 || Galaxy Unpacked, vivo S2, re...  2015-11-12T05:14:19Z
# 2  Bloomberg's Ed Ludlow breaks down Nvidia's lat...  2016-09-01T21:38:32Z
# 3  Tech News 2211 || Xiaomi, Redmi Note 17, Pixel...  2015-11-12T05:14:19Z
# 4  Computing giant Microsoft has spent 20 years p...  2006-04-08T05:51:05Z
#
#                  channel_id       channel_title  category_id  \
# 0  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
# 1  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 2  UCrM7B7SL_g1edFOnmj-SDKg      Bloomberg Tech           25
# 3  UCb-xXZ7ltTvrh9C6DgB9H-Q  Prasadtechintelugu           28
# 4  UC16niRr50-MSBwiO3YDb3RA            BBC News           25
#
#                                                 tags duration  view_count  \
# 0  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT9M43S  7128283600
# 1  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M47S  2188859182
# 2  ['Advisors Capital Management LLC', 'Bessemer ...  PT49M8S   177869185
# 3  ['prasadtechintelugu', 'prasad', 'techtelugu',...  PT8M18S  2188859182
# 4  ['bbc', 'bbc news', 'news', 'world news', 'bre...  PT5M33S  7128283600
#
#    like_count  comment_count  \
# 0       338.0          140.0
# 1      8255.0          304.0
# 2       139.0            8.0
# 3      9297.0          265.0
# 4      2212.0          341.0
#
#                                       thumbnail_url  \
# 0  https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# 1  https://i.ytimg.com/vi/rIj7DnrshxY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/pKsEFQgpe-o/hqdefault.jpg
# 3  https://i.ytimg.com/vi/qnnXBakpLoc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/2JgJ1MRhntg/hqdefault.jpg
#
#                                  channel_description country  \
# 0  Breaking news, live updates and in-depth analy...      GB
# 1  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 2  Welcome to the Bloomberg Tech YouTube channel....     NaN
# 3  Technology , Smartphone Reviews , Unboxing Gad...      IN
# 4  Breaking news, live updates and in-depth analy...      GB
#
#    subscriber_count  video_count   search_keyword search_category  \
# 0          19900000        31890  technology news      Technology
# 1           5140000         5351  technology news      Technology
# 2            732000        13916  technology news      Technology
# 3           5140000         5351  technology news      Technology
# 4          19900000        31890  technology news      Technology
#
#           collected_at
# 0  2026-07-23 13:24:57
# 1  2026-07-23 13:24:57
# 2  2026-07-23 13:24:57
# 3  2026-07-23 13:24:57
# 4  2026-07-23 13:24:57

# %%
df.tail()
# Out:
#          video_id                                              title  \
# 3416  pY4j__UjTd8       Samay Raina - STILL ALIVE Stand Up Reaction!
# 3417  AMrdOj0SqMo  Latinos react to the HOTTEST MALE ACTORS EDITS...
# 3418  tc9Vn8XCZ2E  Reaction Channels are Trending and Viral on Yo...
# 3419  GXg9YOtDrqI  Tom Holland React Viral Videos #tomholland #fu...
# 3420  Odor6c4F2To                           Spicy Pink Food ASMR!? 🥵
#
#                                             description  \
# 3416  Jaby and Achara react to one of the wildest an...
# 3417  The more you tag us the more we serve you,  so...
# 3418  About this video :- Reaction Channels are Tren...
# 3419                                                NaN
# 3420                                     #shorts #short
#
#                      published_at                channel_id    channel_title  \
# 3416         2006-06-10T00:59:23Z  UCwV_A5L1hhEVfld6Wbxn3jg         CineDesi
# 3417         2013-11-18T20:28:18Z  UCPAz3hWHiBC-c1x4K0-atsg  Waleska Herrera
# 3418   2021-07-20T15:38:49.68721Z  UCwOFO2mso90eiBi6g6mOjAg        Drk Talks
# 3419  2026-05-08T02:43:43.373226Z  UCG66zlYKoS3IsxbIfvGcx_w           yanjin
# 3420  2021-02-13T20:11:34.740634Z  UCnwY6Zz-FjqJEeD1Vv6K0bw      LukeDidThat
#
#       category_id                                               tags  \
# 3416           23                            ['trailer', 'reaction']
# 3417           10  ['FEATURE FRIDAY', 'LATINOS REACT', 'SIBLINGS ...
# 3418           28  ['drktalks', 'drk talks', 'deepak ranakoti', '...
# 3419           22                                                NaN
# 3420           24                                                NaN
#
#         duration   view_count  like_count  comment_count  \
# 3416  PT1H52M20S   2407166841     47063.0         1967.0
# 3417    PT21M19S    829601444      2302.0          429.0
# 3418       PT43S    309459220     15152.0          475.0
# 3419       PT45S     28438563     51922.0          265.0
# 3420       PT36S  11648919293   1766253.0        12799.0
#
#                                          thumbnail_url  \
# 3416  https://i.ytimg.com/vi/pY4j__UjTd8/hqdefault.jpg
# 3417  https://i.ytimg.com/vi/AMrdOj0SqMo/hqdefault.jpg
# 3418  https://i.ytimg.com/vi/tc9Vn8XCZ2E/hqdefault.jpg
# 3419  https://i.ytimg.com/vi/GXg9YOtDrqI/hqdefault.jpg
# 3420  https://i.ytimg.com/vi/Odor6c4F2To/hqdefault.jpg
#
#                                     channel_description country  \
# 3416  Trailer reaction-discussions, movie reaction-d...      US
# 3417  I review and react to music from all over the ...      GB
# 3418  Art Of Building Creators!\nTips | Tech | Editi...      IN
# 3419  😂 I rank the most viral clips on the internet....      US
# 3420                               i love spicy food :)      US
#
#       subscriber_count  video_count   search_keyword search_category  \
# 3416           2480000         6722  reaction videos   Entertainment
# 3417           1350000         6678  reaction videos   Entertainment
# 3418           1130000          352  reaction videos   Entertainment
# 3419             57200           19  reaction videos   Entertainment
# 3420          23400000          485  reaction videos   Entertainment
#
#              collected_at
# 3416  2026-07-25 14:04:49
# 3417  2026-07-25 14:04:49
# 3418  2026-07-25 14:04:49
# 3419  2026-07-25 14:04:49
# 3420  2026-07-25 14:04:49

# %%
df.shape
# Out:
# (3421, 20)

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_id',
#        'channel_title', 'category_id', 'tags', 'duration', 'view_count',
#        'like_count', 'comment_count', 'thumbnail_url', 'channel_description',
#        'country', 'subscriber_count', 'video_count', 'search_keyword',
#        'search_category', 'collected_at'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421 entries, 0 to 3420
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             3421 non-null   str
#  1   title                3421 non-null   str
#  2   description          2967 non-null   str
#  3   published_at         3421 non-null   str
#  4   channel_id           3421 non-null   str
#  5   channel_title        3421 non-null   str
#  6   category_id          3421 non-null   int64
#  7   tags                 2438 non-null   str
#  8   duration             3421 non-null   str
#  9   view_count           3421 non-null   int64
#  10  like_count           3311 non-null   float64
#  11  comment_count        3395 non-null   float64
#  12  thumbnail_url        3421 non-null   str
#  13  channel_description  3337 non-null   str
#  14  country              2982 non-null   str
#  15  subscriber_count     3421 non-null   int64
#  16  video_count          3421 non-null   int64
#  17  search_keyword       3421 non-null   str
#  18  search_category      3421 non-null   str
#  19  collected_at         3421 non-null   str
# dtypes: float64(2), int64(4), str(14)
# memory usage: 8.5 MB

# %%
df.isnull().sum()
# Out:
# video_id                 0
# title                    0
# description            454
# published_at             0
# channel_id               0
# channel_title            0
# category_id              0
# tags                   983
# duration                 0
# view_count               0
# like_count             110
# comment_count           26
# thumbnail_url            0
# channel_description     84
# country                439
# subscriber_count         0
# video_count              0
# search_keyword           0
# search_category          0
# collected_at             0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# video_id                0.000000
# title                   0.000000
# description            13.270973
# published_at            0.000000
# channel_id              0.000000
# channel_title           0.000000
# category_id             0.000000
# tags                   28.734288
# duration                0.000000
# view_count              0.000000
# like_count              3.215434
# comment_count           0.760012
# thumbnail_url           0.000000
# channel_description     2.455422
# country                12.832505
# subscriber_count        0.000000
# video_count             0.000000
# search_keyword          0.000000
# search_category         0.000000
# collected_at            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# video_id 3421
# title 3397
# description 2921
# published_at 2185
# channel_id 2185
# channel_title 2184
# category_id 15
# tags 2296
# duration 1554
# view_count 2421
# like_count 3025
# comment_count 1336
# thumbnail_url 3421
# channel_description 2107
# country 57
# subscriber_count 1513
# video_count 1405
# search_keyword 131
# search_category 27
# collected_at 295

# %%
df.describe(include="all")
# Out:
#            video_id                                              title  \
# count          3421                                               3421
# unique         3421                                               3397
# top     r3I1_biJ5Rs  Tom Holland React Viral Videos #tomholland #fu...
# freq              1                                                  4
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                                               description  \
# count                                                2967
# unique                                               2921
# top     *TELEGRAM LINK 📌* \nhttps://t.me/Shivani_Palle...
# freq                                                    7
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                 published_at                channel_id channel_title  \
# count                   3421                      3421          3421
# unique                  2185                      2185          2184
# top     2009-10-29T07:21:23Z  UCsvqVGtbbyHaMoevxPAq9Fg   Simplilearn
# freq                      48                        48            48
# mean                     NaN                       NaN           NaN
# std                      NaN                       NaN           NaN
# min                      NaN                       NaN           NaN
# 25%                      NaN                       NaN           NaN
# 50%                      NaN                       NaN           NaN
# 75%                      NaN                       NaN           NaN
# max                      NaN                       NaN           NaN
#
#         category_id                                               tags  \
# count   3421.000000                                               2438
# unique          NaN                                               2296
# top             NaN  ['C++', 'C++ coding', 'C++ full course', 'C++ ...
# freq            NaN                                                 11
# mean      25.031570                                                NaN
# std        4.112831                                                NaN
# min        1.000000                                                NaN
# 25%       24.000000                                                NaN
# 50%       27.000000                                                NaN
# 75%       27.000000                                                NaN
# max       29.000000                                                NaN
#
#        duration    view_count    like_count  comment_count  \
# count      3421  3.421000e+03  3.311000e+03    3395.000000
# unique     1554           NaN           NaN            NaN
# top        PT1M           NaN           NaN            NaN
# freq         91           NaN           NaN            NaN
# mean        NaN  9.587739e+08  8.025816e+04    1352.471870
# std         NaN  6.883659e+09  3.015098e+05    9382.732982
# min         NaN  3.600000e+03  0.000000e+00       0.000000
# 25%         NaN  1.404919e+07  1.819500e+03      41.000000
# 50%         NaN  8.627173e+07  1.006300e+04     189.000000
# 75%         NaN  4.779345e+08  4.432300e+04     701.500000
# max         NaN  3.493701e+11  6.215914e+06  412557.000000
#
#                                            thumbnail_url  \
# count                                               3421
# unique                                              3421
# top     https://i.ytimg.com/vi/r3I1_biJ5Rs/hqdefault.jpg
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                       channel_description country  \
# count                                                3337    2982
# unique                                               2107      57
# top     Simplilearn is the world’s leading online trai...      IN
# freq                                                   48    1405
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#         subscriber_count    video_count       search_keyword  \
# count       3.421000e+03    3421.000000                 3421
# unique               NaN            NaN                  131
# top                  NaN            NaN  consumer technology
# freq                 NaN            NaN                   56
# mean        2.869975e+06    5461.394037                  NaN
# std         1.152265e+07   31189.264339                  NaN
# min         2.200000e+01       1.000000                  NaN
# 25%         7.850000e+04     256.000000                  NaN
# 50%         5.450000e+05     737.000000                  NaN
# 75%         2.410000e+06    1792.000000                  NaN
# max         5.090000e+08  665951.000000                  NaN
#
#          search_category         collected_at
# count               3421                 3421
# unique                27                  295
# top     Personal Finance  2026-07-23 13:24:57
# freq                 284                   20
# mean                 NaN                  NaN
# std                  NaN                  NaN
# min                  NaN                  NaN
# 25%                  NaN                  NaN
# 50%                  NaN                  NaN
# 75%                  NaN                  NaN
# max                  NaN                  NaN

# %%
print(df.columns.tolist())
# Out:
# ['video_id', 'title', 'description', 'published_at', 'channel_id', 'channel_title', 'category_id', 'tags', 'duration', 'view_count', 'like_count', 'comment_count', 'thumbnail_url', 'channel_description', 'country', 'subscriber_count', 'video_count', 'search_keyword', 'search_category', 'collected_at']

# %% [markdown]
# **Negative Values**

# %%
numeric_cols = [
    "view_count",
    "like_count",
    "comment_count",
    "subscriber_count",
]

(df[numeric_cols] < 0).sum()
# Out:
# view_count          0
# like_count          0
# comment_count       0
# subscriber_count    0
# dtype: int64

# %% [markdown]
# Zero Values

# %%
(df[numeric_cols] == 0).sum()
# Out:
# view_count           0
# like_count           1
# comment_count       96
# subscriber_count     0
# dtype: int64
