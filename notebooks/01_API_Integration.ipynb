# %% [markdown]
# **Imports**

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# **Configuration**

# %%
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv(override=True)

# Read API key from .env
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")

# Optional: Verify it's loaded
print(YOUTUBE_API_KEY[:12])

SEARCH_URL = "https://www.googleapis.com/youtube/v3/search"
# Out:
# AIzaSyA2pJ_J

# %% [markdown]
# **Parameters**

# %%
params = {
    "part": "snippet",
    "q": "Python Programming",
    "type": "video",
    "maxResults": 5,
    "key": YOUTUBE_API_KEY
}

# %% [markdown]
# **API Request**

# %%
response = requests.get(SEARCH_URL, params=params)
print(response.status_code)
print("Key sent:", params["key"][:12])
print("Final URL:", response.request.url)
print(response.text)
# Out:
# 200
# Key sent: AIzaSyA2pJ_J
# Final URL: https://www.googleapis.com/youtube/v3/search?part=snippet&q=Python+Programming&type=video&maxResults=5&key=AIzaSyA2pJ_Jctt7D4EtJ1vneNwu5-qoBwzUXxs
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "PENi2HYaNhtDSrezmiyUD8Q7mT8",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "IN",
#   "pageInfo": {
#     "totalResults": 469196,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "8a7GjkSL6bmqUPz2_aHW0wObfzM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kqtD5dpn9C8"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. ⚡ Plus, get 6 months of PyCharm FREE with ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-16T13:00:20Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "I_rlcUmBoHxZk5fXbvvCvJi1MSs",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "_uQrJ0TkZlc"
#       },
#       "snippet": {
#         "publishedAt": "2019-02-18T15:00:08Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Learn Python for AI, machine learning, and web development with this beginner-friendly course! Get 6 months of PyCharm ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2019-02-18T15:00:08Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "bwuFDP_9ff3KepvpKyKZ6JxME0A",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "80yIVH2aOy0"
#       },
#       "snippet": {
#         "publishedAt": "2025-06-06T00:51:25Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "python programming|python for beginners|python full course",
#         "description": "python programming|python for beginners|python full course @monuinstitute python tutorial, learn python, python basics, ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "liveBroadcastContent": "none",
#         "publishTime": "2025-06-06T00:51:25Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Nzo8Ch18Mn213UVPaSsfcSyanF0",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "GfWRxr1OBm4"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-29T01:57:30Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#         "description": "Python Basics: The Best Way to Learn Python Programming (2024) @monuinstitute Some of you asked me about Python ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-29T01:57:30Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "omansXP1JMbWLZPcYAMI2wag_iE",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "K5KVEU3aaeQ"
#       },
#       "snippet": {
#         "publishedAt": "2025-02-12T12:30:31Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Master Python from scratch No fluff—just clear, practical coding skills to kickstart your journey! Want to dive deeper? - Check ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2025-02-12T12:30:31Z"
#       }
#     }
#   ]
# }

# %%
if response.status_code != 200:
    print("Status Code:", response.status_code)
    print("Response:")
    print(response.text)

response.raise_for_status()

# %% [markdown]
# **Convert to JSON**

# %%
data = response.json()

# %% [markdown]
# **Inspect JSON**

# %%
print(json.dumps(data, indent = 2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "rtkchKAyrX7rJo6z5MazU_0Xwb8",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "IN",
#   "pageInfo": {
#     "totalResults": 469943,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Zv6GlZT0UA_uATA9CFostwMyiAc",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "DInMru2Eq6E"
#       },
#       "snippet": {
#         "publishedAt": "2022-08-26T14:30:02Z",
#         "channelId": "UCM-yUTYGmrNvKOCcAl21g3w",
#         "title": "Introduction to Python Programming | Python for Beginners #lec1",
#         "description": "Jenny's Lectures Mastering DSA with Java course(New Batch): ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Jenny's Lectures CS IT",
#         "liveBroadcastContent": "none",
#         "publishTime": "2022-08-26T14:30:02Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Nzo8Ch18Mn213UVPaSsfcSyanF0",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "GfWRxr1OBm4"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-29T01:57:30Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#         "description": "Python Basics: The Best Way to Learn Python Programming (2024) @monuinstitute Some of you asked me about Python ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-29T01:57:30Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "8a7GjkSL6bmqUPz2_aHW0wObfzM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kqtD5dpn9C8"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-16T13:00:20Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "FOtoNmHgPiZ4LaFAvK2vCueFwFo",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "fWjsdhR3z3c"
#       },
#       "snippet": {
#         "publishedAt": "2021-05-26T12:32:40Z",
#         "channelId": "UCuudpdbKmQWq2PPzYgVCWlA",
#         "title": "Learn Python in Less than 10 Minutes for Beginners (Fast &amp; Easy)",
#         "description": "In this crash course I'll be teaching you the basics of Python in less than 10 minutes. Python is super easy to learn compared to ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Indently",
#         "liveBroadcastContent": "none",
#         "publishTime": "2021-05-26T12:32:40Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "gD2UFQyJsxhoty5V5FSKguvP6Ck",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "nluUYtejoIE"
#       },
#       "snippet": {
#         "publishedAt": "2024-06-21T07:55:33Z",
#         "channelId": "UCAy1PN6jrZXrGFg79WP_91A",
#         "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#         "description": "In this quick tutorial, I'll show you how to write your very first line of Python code: the classic \"Hello, World!\" \u2728 Whether you're a ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "The Programmers Realm",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-06-21T07:55:33Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# **Videos API ENDPOINT**

# %%
VIDEOS_URL = "https://www.googleapis.com/youtube/v3/videos"

# %% [markdown]
# **EXTRACT VIDEO IDS**

# %%
video_ids = []
for item in data["items"]:
    video_ids.append(item["id"]["videoId"])

print(video_ids)
# Out:
# ['DInMru2Eq6E', 'GfWRxr1OBm4', 'kqtD5dpn9C8', 'fWjsdhR3z3c', 'nluUYtejoIE']

# %%
video_ids = ",".join(video_ids)
print(video_ids)
# Out:
# DInMru2Eq6E,GfWRxr1OBm4,kqtD5dpn9C8,fWjsdhR3z3c,nluUYtejoIE

# %% [markdown]
# **VIDEOS API PARAMETERS**

# %%
video_params = {
    "part": "snippet,statistics,contentDetails",
    "id": video_ids,
    "key": YOUTUBE_API_KEY
}

# %% [markdown]
# **Call Videos API**

# %%
video_response = requests.get(VIDEOS_URL, params=video_params)
print(video_response.status_code)
# Out:
# 200

# %%
video_data = video_response.json()

# %%
print(json.dumps(video_data, indent = 2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "HJ1wv0nEbrliy3CW2-DrJ0fLuWo",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "0LqUjju02_hVZfWJHMs_iwc5bUM",
#       "id": "DInMru2Eq6E",
#       "snippet": {
#         "publishedAt": "2022-08-26T14:30:02Z",
#         "channelId": "UCM-yUTYGmrNvKOCcAl21g3w",
#         "title": "Introduction to Python Programming | Python for Beginners #lec1",
#         "description": "\ud83d\udd25 Jenny's Lectures Mastering DSA with Java course(New Batch): \nhttps://www.jennyslectures.com/courses/Mastering-DSA-with-JAVA-2-68ce8b083425e77d71739441\n\n\u26a1 Limited seats! First 500 students get an extra 20% OFF with coupon: BEST500\n\nJenny's Lectures JAVA from Scratch Course: https://www.jennyslectures.com/courses/Java-From-Scratch-67c9a7244b2225248cf88385\n\nGenAI Course for beginners: https://www.jennyslectures.com/courses/Generative-AI-for-Beginners-From-Basics-to-Chatbot-Creation-68584c28a81c363f9f037df1\n\n\ud83d\udd25Notes of Today's Class: https://drive.google.com/file/d/1WjmeotoY7iwtYVe_W90j6k3a-pGoPCWQ/view?usp=sharing\n******************************************************\n\nConnect & Contact Me:\n\nFacebook: https://www.facebook.com/Jennys-Lectures-CSIT-Netjrf-316814368950701/\nInstagram: https://www.instagram.com/jayantikhatrilamba/\nTwitter: https://twitter.com/KhatriJenny\nLinkedIn: https://www.linkedin.com/in/jayanti-khatri-32653817/\n\n*******************************************************\nMore Playlists:\n\n\ud83d\udd25Python Tutorials for Beginners: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bZSiqiOL5ta39vSnBxpOPT\nC complete playlist: https://www.youtube.com/playlist?list=PLdo5W4Nhv31a8UcMN9-35ghv8qyFWD9_S\nC++ Complete Playlist: https://www.youtube.com/watch?v=KYxLEDF6kjs&list=PLdo5W4Nhv31YU5Wx1dopka58teWP9aCee\nPlacement Series: https://www.youtube.com/playlist?list=PLdo5W4Nhv31YvlDpJhvOYbM9Ap8UypgEy\nData Structures and Algorithms: https: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bbKJzrsKfMpo_grxuLl8LU\nDesign and Analysis of Algorithms(DAA): https://www.youtube.com/playlist?list=PLdo5W4Nhv31ZTn2P9vF02bkb3SC8uiUUn\nDynamic Programming: https://www.youtube.com/playlist?list=PLdo5W4Nhv31aBrJE1WS4MR9LRfbmZrAQu\nOperating Systems: //www.youtube.com/playlist?list=PLdo5W4Nhv31a5ucW_S1K3-x6ztBRD-PNa\nDBMS: https://www.youtube.com/playlist?list=PLdo5W4Nhv31b33kF46f9aFjoJPOkdlsRc\n#python #programming #jennyslectures",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Jenny's Lectures CS IT",
#         "tags": [
#           "operating system",
#           "data structure and algorithms",
#           "jayanti khatri lamba",
#           "jennys lectures",
#           "jennys lectures baby",
#           "C++",
#           "C++ complete course",
#           "c++ placement course",
#           "gate cs lectures",
#           "ugc net computer science preparation",
#           "ugc net syllabus",
#           "c++ jennys lectures",
#           "object oriented programming in C++",
#           "introduction to python programming",
#           "python full course for beginners",
#           "python jennys lectures",
#           "java programming",
#           "best channel to learn programming",
#           "c programming"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Introduction to Python Programming | Python for Beginners #lec1",
#           "description": "\ud83d\udd25 Jenny's Lectures Mastering DSA with Java course(New Batch): \nhttps://www.jennyslectures.com/courses/Mastering-DSA-with-JAVA-2-68ce8b083425e77d71739441\n\n\u26a1 Limited seats! First 500 students get an extra 20% OFF with coupon: BEST500\n\nJenny's Lectures JAVA from Scratch Course: https://www.jennyslectures.com/courses/Java-From-Scratch-67c9a7244b2225248cf88385\n\nGenAI Course for beginners: https://www.jennyslectures.com/courses/Generative-AI-for-Beginners-From-Basics-to-Chatbot-Creation-68584c28a81c363f9f037df1\n\n\ud83d\udd25Notes of Today's Class: https://drive.google.com/file/d/1WjmeotoY7iwtYVe_W90j6k3a-pGoPCWQ/view?usp=sharing\n******************************************************\n\nConnect & Contact Me:\n\nFacebook: https://www.facebook.com/Jennys-Lectures-CSIT-Netjrf-316814368950701/\nInstagram: https://www.instagram.com/jayantikhatrilamba/\nTwitter: https://twitter.com/KhatriJenny\nLinkedIn: https://www.linkedin.com/in/jayanti-khatri-32653817/\n\n*******************************************************\nMore Playlists:\n\n\ud83d\udd25Python Tutorials for Beginners: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bZSiqiOL5ta39vSnBxpOPT\nC complete playlist: https://www.youtube.com/playlist?list=PLdo5W4Nhv31a8UcMN9-35ghv8qyFWD9_S\nC++ Complete Playlist: https://www.youtube.com/watch?v=KYxLEDF6kjs&list=PLdo5W4Nhv31YU5Wx1dopka58teWP9aCee\nPlacement Series: https://www.youtube.com/playlist?list=PLdo5W4Nhv31YvlDpJhvOYbM9Ap8UypgEy\nData Structures and Algorithms: https: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bbKJzrsKfMpo_grxuLl8LU\nDesign and Analysis of Algorithms(DAA): https://www.youtube.com/playlist?list=PLdo5W4Nhv31ZTn2P9vF02bkb3SC8uiUUn\nDynamic Programming: https://www.youtube.com/playlist?list=PLdo5W4Nhv31aBrJE1WS4MR9LRfbmZrAQu\nOperating Systems: //www.youtube.com/playlist?list=PLdo5W4Nhv31a5ucW_S1K3-x6ztBRD-PNa\nDBMS: https://www.youtube.com/playlist?list=PLdo5W4Nhv31b33kF46f9aFjoJPOkdlsRc\n#python #programming #jennyslectures"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT11M14S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1667276",
#         "likeCount": "28200",
#         "favoriteCount": "0",
#         "commentCount": "946"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "jmqZyBA52Gj7n-akuV5oUK2qdB0",
#       "id": "GfWRxr1OBm4",
#       "snippet": {
#         "publishedAt": "2024-12-29T01:57:30Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#         "description": "Python Basics: The Best Way to Learn Python Programming (2024)\n\ud83d\udc49@monuinstitute\n\nSome of you asked me about Python courses for further learning. I strongly recommend you not to buy any overpriced course. One of the most underrated resources in the journey of programmers is Udemy (This post is not sponsored).\nThe affordable courses Udemy provides with doubt support are way way better than most of the paid courses I see online these days. Here are some of my top picks with discount applied for you:\nPython is one of the most demanded programming languages in the job market. Surprisingly, it is equally easy to learn and master  Python. This python tutorial for absolute beginners in Hindi series will focus on teaching you python concepts from the ground up. Today we will see some of the mindblowing python programs, I created.\n\nTopic:\n1) python coding \n2) python language \n3) python programming \n4) python course \n5) python import library \n6) python graphics \n7) python tutorial \n8) python import statement \n9) python project \n10) python complete course \n11)monu institute \n\nTags:\npython for beginners\npython projects\ndata science python\n python tutorial\n learn python\npython course\ncoding for beginners\npython tips\npython scripting\npython automation\ndata analysis\npython automation projects\nhow to learn python\n python programming\npython basics\nlearn python from scratch\n coding\npython tricks\nprogramming skills\npython tutorial for beginners\n python tutorials\n data analysis python\ncode\nprogramming\n advanced python\n python scripts\n\nHashtags:\n#python #coding #code #cod #pythonprogramming #computerscience #computerknowledge #computer #learning #learncoding #codelover #computers #education #educational #educational\n\nHello dosto video se sambandhit sujhav dene ke liye neech diye gye email sujhav de sakte hai\n\ud83d\udc49 E-mail: mv8293399@gmail.com",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "tags": [
#           "advanced python",
#           "code",
#           "coding",
#           "coding for beginners",
#           "data analysis",
#           "data analysis python",
#           "data science python",
#           "how to learn python",
#           "learn python",
#           "learn python from scratch",
#           "programming",
#           "programming skills",
#           "python automation",
#           "python automation projects",
#           "python basics",
#           "python course",
#           "python for beginners",
#           "python programming",
#           "python projects",
#           "python scripting",
#           "python scripts",
#           "python tips",
#           "python tricks",
#           "python tutorial",
#           "python tutorial for beginners",
#           "python tutorials"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-IN",
#         "localized": {
#           "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#           "description": "Python Basics: The Best Way to Learn Python Programming (2024)\n\ud83d\udc49@monuinstitute\n\nSome of you asked me about Python courses for further learning. I strongly recommend you not to buy any overpriced course. One of the most underrated resources in the journey of programmers is Udemy (This post is not sponsored).\nThe affordable courses Udemy provides with doubt support are way way better than most of the paid courses I see online these days. Here are some of my top picks with discount applied for you:\nPython is one of the most demanded programming languages in the job market. Surprisingly, it is equally easy to learn and master  Python. This python tutorial for absolute beginners in Hindi series will focus on teaching you python concepts from the ground up. Today we will see some of the mindblowing python programs, I created.\n\nTopic:\n1) python coding \n2) python language \n3) python programming \n4) python course \n5) python import library \n6) python graphics \n7) python tutorial \n8) python import statement \n9) python project \n10) python complete course \n11)monu institute \n\nTags:\npython for beginners\npython projects\ndata science python\n python tutorial\n learn python\npython course\ncoding for beginners\npython tips\npython scripting\npython automation\ndata analysis\npython automation projects\nhow to learn python\n python programming\npython basics\nlearn python from scratch\n coding\npython tricks\nprogramming skills\npython tutorial for beginners\n python tutorials\n data analysis python\ncode\nprogramming\n advanced python\n python scripts\n\nHashtags:\n#python #coding #code #cod #pythonprogramming #computerscience #computerknowledge #computer #learning #learncoding #codelover #computers #education #educational #educational\n\nHello dosto video se sambandhit sujhav dene ke liye neech diye gye email sujhav de sakte hai\n\ud83d\udc49 E-mail: mv8293399@gmail.com"
#         },
#         "defaultAudioLanguage": "hi"
#       },
#       "contentDetails": {
#         "duration": "PT9S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "2806016",
#         "likeCount": "36562",
#         "favoriteCount": "0",
#         "commentCount": "302"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "ussKM0PJUT2P3pyna03rHUphhs4",
#       "id": "kqtD5dpn9C8",
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "code with mosh",
#           "introduction to python",
#           "learn python",
#           "learn python programming",
#           "mosh hamedani",
#           "programming",
#           "programming with mosh",
#           "python",
#           "python 2020",
#           "python 3",
#           "python basics",
#           "python course",
#           "python crash course",
#           "python for beginners",
#           "python from scratch",
#           "python programming",
#           "python tutorial",
#           "python tutorial for beginners",
#           "web development"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#           "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT1H6S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "24784151",
#         "likeCount": "561427",
#         "favoriteCount": "0",
#         "commentCount": "28281"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "SzzdJbocGyeZujd0MjxcYJwU-nk",
#       "id": "fWjsdhR3z3c",
#       "snippet": {
#         "publishedAt": "2021-05-26T12:32:40Z",
#         "channelId": "UCuudpdbKmQWq2PPzYgVCWlA",
#         "title": "Learn Python in Less than 10 Minutes for Beginners (Fast & Easy)",
#         "description": "In this crash course I'll be teaching you the basics of Python in less than 10 minutes. Python is super easy to learn compared to the other languages!\n\nDownload Python: https://www.python.org/\nDownload PyCharm: https://www.jetbrains.com/pycharm/download/",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/fWjsdhR3z3c/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Indently",
#         "tags": [
#           "code palace",
#           "cde palace",
#           "code palce",
#           "palace code"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-GB",
#         "localized": {
#           "title": "Learn Python in Less than 10 Minutes for Beginners (Fast & Easy)",
#           "description": "In this crash course I'll be teaching you the basics of Python in less than 10 minutes. Python is super easy to learn compared to the other languages!\n\nDownload Python: https://www.python.org/\nDownload PyCharm: https://www.jetbrains.com/pycharm/download/"
#         },
#         "defaultAudioLanguage": "en-GB"
#       },
#       "contentDetails": {
#         "duration": "PT10M30S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1537427",
#         "likeCount": "34982",
#         "favoriteCount": "0",
#         "commentCount": "868"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "zfyFAvpcCIY3KYdLEM2CYWjsrdE",
#       "id": "nluUYtejoIE",
#       "snippet": {
#         "publishedAt": "2024-06-21T07:55:33Z",
#         "channelId": "UCAy1PN6jrZXrGFg79WP_91A",
#         "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#         "description": "In this quick tutorial, I\u2019ll show you how to write your very first line of Python code: the classic \"Hello, World!\" \ud83c\udf0d\u2728\n\nWhether you're a total beginner or brushing up on your basics, this video will get you started in under a minute. \ud83d\ude80\n\n\n\nDon't forget to like, subscribe, and leave a comment on what you want to learn next! \ud83d\udd25\n\nJoin me in the PROGRAMMER'S REALM!\n\n#Python #Programming #HelloWorld #PythonTutorial #LearnToCode #CodingForBeginners #TheProgrammersRealm",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "The Programmers Realm",
#         "tags": [
#           "python",
#           "programming",
#           "helloworld",
#           "pythontutorial",
#           "learntocode",
#           "codingforbeginners",
#           "theprogrammersrealm"
#         ],
#         "categoryId": "28",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#           "description": "In this quick tutorial, I\u2019ll show you how to write your very first line of Python code: the classic \"Hello, World!\" \ud83c\udf0d\u2728\n\nWhether you're a total beginner or brushing up on your basics, this video will get you started in under a minute. \ud83d\ude80\n\n\n\nDon't forget to like, subscribe, and leave a comment on what you want to learn next! \ud83d\udd25\n\nJoin me in the PROGRAMMER'S REALM!\n\n#Python #Programming #HelloWorld #PythonTutorial #LearnToCode #CodingForBeginners #TheProgrammersRealm"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT25S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "true",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1467250",
#         "likeCount": "19380",
#         "favoriteCount": "0",
#         "commentCount": "152"
#       }
#     }
#   ],
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# **Channels API ENDPOINT**

# %%
CHANNELS_URL = "https://www.googleapis.com/youtube/v3/channels"

# %%
channel_ids = []

for item in video_data["items"]:
    channel_ids.append(item["snippet"]["channelId"])

print(channel_ids)
# Out:
# ['UCM-yUTYGmrNvKOCcAl21g3w', 'UCMUuCs6Y1WzDpAKg_2W-3yA', 'UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCuudpdbKmQWq2PPzYgVCWlA', 'UCAy1PN6jrZXrGFg79WP_91A']

# %%
channel_ids = list(set(channel_ids))

print(channel_ids)
# Out:
# ['UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCuudpdbKmQWq2PPzYgVCWlA', 'UCM-yUTYGmrNvKOCcAl21g3w', 'UCMUuCs6Y1WzDpAKg_2W-3yA', 'UCAy1PN6jrZXrGFg79WP_91A']

# %%
channel_ids = ",".join(channel_ids)

print(channel_ids)
# Out:
# UCWv7vMbMWH4-V0ZXdmDpPBA,UCuudpdbKmQWq2PPzYgVCWlA,UCM-yUTYGmrNvKOCcAl21g3w,UCMUuCs6Y1WzDpAKg_2W-3yA,UCAy1PN6jrZXrGFg79WP_91A

# %%
channel_params = {
    "part": "snippet,statistics",
    "id": channel_ids,
    "key": YOUTUBE_API_KEY
}

# %%
channel_response = requests.get(CHANNELS_URL, params=channel_params)
print(channel_response.status_code)
# Out:
# 200

# %%
channel_data = channel_response.json()

# %%
print(json.dumps(channel_data, indent = 2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "Y2Ug7KRyE8vptgoft4ZTWlz90CY",
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#channel",
#       "etag": "p5TwAKEEuyY9Bu5rFsU2dTi2_XQ",
#       "id": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#       "snippet": {
#         "title": "Monu institute ",
#         "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906",
#         "customUrl": "@monuinstitute",
#         "publishedAt": "2024-12-15T14:37:58.113164Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Monu institute ",
#           "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906"
#         },
#         "country": "IN"
#       },
#       "statistics": {
#         "viewCount": "8284838",
#         "subscriberCount": "9020",
#         "hiddenSubscriberCount": false,
#         "videoCount": "128"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "LEqJbPFiEid0xR0fLad7Eth4qr0",
#       "id": "UCuudpdbKmQWq2PPzYgVCWlA",
#       "snippet": {
#         "title": "Indently",
#         "description": "Simple is better than complex_\n",
#         "customUrl": "@indently",
#         "publishedAt": "2019-09-01T18:06:19Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/68ZQuFvv8mZTJQD65biYl2BWjKKMxkDS5k_sIdAGpRY9-p1vYsqwE1jNMTDEveZoSpkfOpKG=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/68ZQuFvv8mZTJQD65biYl2BWjKKMxkDS5k_sIdAGpRY9-p1vYsqwE1jNMTDEveZoSpkfOpKG=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/68ZQuFvv8mZTJQD65biYl2BWjKKMxkDS5k_sIdAGpRY9-p1vYsqwE1jNMTDEveZoSpkfOpKG=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Indently",
#           "description": "Simple is better than complex_\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "47035986",
#         "subscriberCount": "360000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "1039"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "xi2HKdDD204NBIAyRrSuWW_Qqz8",
#       "id": "UCM-yUTYGmrNvKOCcAl21g3w",
#       "snippet": {
#         "title": "Jenny's Lectures CS IT",
#         "description": "Warm Welcome to Jenny's Lectures. On This Channel we are focusing on creating tutorials for  engineers, software developers, programmers, Coders, undergraduates, graduates. We cover topics for all different skill levels, so whether you are a beginner or have some years of experience, this channel will have something for you.\n\nWe've already uploaded a wide variety of videos on topics that include: JAVA,C, C++, Python, Computer Science Fundamentals, Computer Science subjects like OS, DBMS, Data Structures, DSA, DAA, Placement Series, GATE Coaching Videos, UGC NET syllabus Videos and plenty of other tips and tricks which will help you in your career.\n\n",
#         "customUrl": "@jennyslecturescsit",
#         "publishedAt": "2019-01-19T18:46:22Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Jenny's Lectures CS IT",
#           "description": "Warm Welcome to Jenny's Lectures. On This Channel we are focusing on creating tutorials for  engineers, software developers, programmers, Coders, undergraduates, graduates. We cover topics for all different skill levels, so whether you are a beginner or have some years of experience, this channel will have something for you.\n\nWe've already uploaded a wide variety of videos on topics that include: JAVA,C, C++, Python, Computer Science Fundamentals, Computer Science subjects like OS, DBMS, Data Structures, DSA, DAA, Placement Series, GATE Coaching Videos, UGC NET syllabus Videos and plenty of other tips and tricks which will help you in your career.\n\n"
#         },
#         "country": "IN"
#       },
#       "statistics": {
#         "viewCount": "294112715",
#         "subscriberCount": "2090000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "930"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "wp80z8ikxtUnYJAGGeBfREDRekM",
#       "id": "UCAy1PN6jrZXrGFg79WP_91A",
#       "snippet": {
#         "title": "The Programmers Realm",
#         "description": "Welcome to The Programmers Realm! \ud83d\ude80\n\nDive into the world of coding and technology with me, where we explore the essentials of Python programming, web development, networking and anything computers! Whether you're a beginner taking your first steps or an advanced programmer looking to refine your skills, we've got something for everyone \u2728\n\nWhat's your coding goal? Share your thoughts and projects in the comments, and let's build the future together! \ud83c\udf10\ud83d\udcbb\n\n#Python #Programming #WebDevelopment #Networking #LearnToCode #TheProgrammersRealm #CodingForBeginners #WebDevelopment #Code #vscode #javascript #networking #network  #webdevelopment #webseries \n\nA \"TFR\" brand.\n",
#         "customUrl": "@programmersrealm",
#         "publishedAt": "2023-07-06T06:35:12.290436Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "The Programmers Realm",
#           "description": "Welcome to The Programmers Realm! \ud83d\ude80\n\nDive into the world of coding and technology with me, where we explore the essentials of Python programming, web development, networking and anything computers! Whether you're a beginner taking your first steps or an advanced programmer looking to refine your skills, we've got something for everyone \u2728\n\nWhat's your coding goal? Share your thoughts and projects in the comments, and let's build the future together! \ud83c\udf10\ud83d\udcbb\n\n#Python #Programming #WebDevelopment #Networking #LearnToCode #TheProgrammersRealm #CodingForBeginners #WebDevelopment #Code #vscode #javascript #networking #network  #webdevelopment #webseries \n\nA \"TFR\" brand.\n"
#         },
#         "country": "AU"
#       },
#       "statistics": {
#         "viewCount": "2216984",
#         "subscriberCount": "7380",
#         "hiddenSubscriberCount": false,
#         "videoCount": "23"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "vkoTv7Zx1imqJ4F-rLFSG9enSb8",
#       "id": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#       "snippet": {
#         "title": "Programming with Mosh",
#         "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n",
#         "customUrl": "@programmingwithmosh",
#         "publishedAt": "2014-10-07T00:40:53Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Programming with Mosh",
#           "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "275659811",
#         "subscriberCount": "5110000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "246"
#       }
#     }
#   ]
# }
