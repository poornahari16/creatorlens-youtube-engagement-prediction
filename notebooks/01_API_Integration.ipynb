# %% [markdown]
# **Imports**

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# **Configuration**

# %%
API_KEY = "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
SEARCH_URL = "https://www.googleapis.com/youtube/v3/search"

# %% [markdown]
# **Parameters**

# %%
params = {
    "part": "snippet",
    "q": "Python Programming",
    "type": "video",
    "maxResults": 5,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **API Request**

# %%
response = requests.get(SEARCH_URL, params=params)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# **Convert to JSON**

# %%
data = response.json()

# %% [markdown]
# **Inspect JSON**

# %%
print(json.dumps(data, indent = 2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "knrU9URsE314nj0BTBif2SQO5wg",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "IN",
#   "pageInfo": {
#     "totalResults": 472393,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "8a7GjkSL6bmqUPz2_aHW0wObfzM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kqtD5dpn9C8"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-16T13:00:20Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "I_rlcUmBoHxZk5fXbvvCvJi1MSs",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "_uQrJ0TkZlc"
#       },
#       "snippet": {
#         "publishedAt": "2019-02-18T15:00:08Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Learn Python for AI, machine learning, and web development with this beginner-friendly course! Get 6 months of PyCharm ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2019-02-18T15:00:08Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "O_4Mn5-OuMj2btaUJ_JJAjPRobs",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "2xZJk8Vaxvk"
#       },
#       "snippet": {
#         "publishedAt": "2026-07-20T06:41:41Z",
#         "channelId": "UCCrEpVALr901PP01fkVo58g",
#         "title": "If Code Works Don&#39;t Touch It !! #coding #programming #python #shorts",
#         "description": "WELCOME TO Aziz Codex \u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501 Hi, I'm Ali Aziz \u2014 Web Developer, Coder, Animation ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "\ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05",
#         "liveBroadcastContent": "none",
#         "publishTime": "2026-07-20T06:41:41Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "ALaQyozfZ-ky8b74UcpItcqWUeA",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "q2-pnQffZik"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp Source: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-31T02:30:33Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "bwuFDP_9ff3KepvpKyKZ6JxME0A",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "80yIVH2aOy0"
#       },
#       "snippet": {
#         "publishedAt": "2025-06-06T00:51:25Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "python programming|python for beginners|python full course",
#         "description": "python programming|python for beginners|python full course @monuinstitute python tutorial, learn python, python basics, ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "liveBroadcastContent": "none",
#         "publishTime": "2025-06-06T00:51:25Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# **Videos API ENDPOINT**

# %%
VIDEOS_URL = "https://www.googleapis.com/youtube/v3/videos"

# %% [markdown]
# **EXTRACT VIDEO IDS**

# %%
video_ids = []
for item in data["items"]:
    video_ids.append(item["id"]["videoId"])

print(video_ids)
# Out:
# ['kqtD5dpn9C8', '_uQrJ0TkZlc', '2xZJk8Vaxvk', 'q2-pnQffZik', '80yIVH2aOy0']

# %%
video_ids = ",".join(video_ids)
print(video_ids)
# Out:
# kqtD5dpn9C8,_uQrJ0TkZlc,2xZJk8Vaxvk,q2-pnQffZik,80yIVH2aOy0

# %% [markdown]
# **VIDEOS API PARAMETERS**

# %%
video_params = {
    "part": "snippet,statistics,contentDetails",
    "id": video_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **Call Videos API**

# %%
video_response = requests.get(VIDEOS_URL, params=video_params)
print(video_response.status_code)
# Out:
# 200

# %%
video_data = video_response.json()

# %%
print(json.dumps(video_data, indent = 2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "7P9CnuKlLjpERMY1gHCXrqPRf0I",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "Gm6nkv0qWAKSbX9yjiYXhrFE3pM",
#       "id": "kqtD5dpn9C8",
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "code with mosh",
#           "introduction to python",
#           "learn python",
#           "learn python programming",
#           "mosh hamedani",
#           "programming",
#           "programming with mosh",
#           "python",
#           "python 2020",
#           "python 3",
#           "python basics",
#           "python course",
#           "python crash course",
#           "python for beginners",
#           "python from scratch",
#           "python programming",
#           "python tutorial",
#           "python tutorial for beginners",
#           "web development"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#           "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT1H6S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "24729452",
#         "likeCount": "560543",
#         "favoriteCount": "0",
#         "commentCount": "28229"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "MFBRhn1zLI_nIJejE1bS252YhwU",
#       "id": "_uQrJ0TkZlc",
#       "snippet": {
#         "publishedAt": "2019-02-18T15:00:08Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Learn Python for AI, machine learning, and web development with this beginner-friendly course! \ud83d\ude80 Get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper?\n- Check out my Python mastery course: https://mosh.link/python-course\n- Subscribe for more awesome Python content: https://goo.gl/6PYaGF\n\n\ud83d\udd17 Related videos \nhttps://youtu.be/yVl_G-F7m8c?si=aoIiT6CyaRRfBsRM\n\n\ud83d\udc49 New version available Watch here: https://youtu.be/kqtD5dpn9C8\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Supplementary materials (spreadsheet): https://github.com/mosh-hamedani/python-supplementary-materials\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 My favorite Python books\n- Python Crash Course: https://amzn.to/2GqMdjG\n- Automate the Boring Stuff with Python: https://amzn.to/2N71d6S\n- A Smarter Way to Learn Python: https://amzn.to/2UZa6lE\n- Machine Learning for Absolute Beginners: https://amzn.to/2Gs0koL\n- Hands-on Machine Learning with scikit-learn and TensorFlow: https://amzn.to/2IdUuJy\n\n\ud83d\udcd6 TABLE OF CONTENT\n00:00:00 Introduction\n00:01:49 Installing Python 3\n00:06:10 Your First Python Program\n00:08:11 How Python Code Gets Executed \n00:11:24 How Long It Takes To Learn Python \n00:13:03 Variables\n00:18:21 Receiving Input\n00:22:16 Python Cheat Sheet\n00:22:46 Type Conversion\n00:29:31 Strings\n00:37:36 Formatted Strings\n00:40:50 String Methods\n00:48:33 Arithmetic Operations\n00:51:33 Operator Precedence\n00:55:04 Math Functions\n00:58:17 If Statements\n01:06:32 Logical Operators\n01:11:25 Comparison Operators\n01:16:17 Weight Converter Program \n01:20:43 While Loops\n01:24:07 Building a Guessing Game\n01:30:51 Building the Car Game\n01:41:48 For Loops\n01:47:46 Nested Loops\n01:55:50 Lists\n02:01:45 2D Lists\n02:05:11 My Complete Python Course \n02:06:00 List Methods\n02:13:25 Tuples\n02:15:34 Unpacking\n02:18:21 Dictionaries\n02:26:21 Emoji Converter\n02:30:31 Functions\n02:35:21 Parameters\n02:39:24 Keyword Arguments \n02:44:45 Return Statement\n02:48:55 Creating a Reusable Function \n02:53:42 Exceptions\n02:59:14 Comments\n03:01:46 Classes\n03:07:46 Constructors\n03:14:41 Inheritance\n03:19:33 Modules\n03:30:12 Packages\n03:36:22 Generating Random Values\n03:44:37 Working with Directories \n03:50:47 Pypi and Pip\n03:55:34 Project 1: Automation with Python\n04:10:22 Project 2: Machine Learning with Python \n04:58:37 Project 3: Building a Website with Django\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/_uQrJ0TkZlc/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "python tutorial",
#           "python",
#           "python for beginners",
#           "python tutorial for beginners",
#           "learn python",
#           "python crash course",
#           "python 2019",
#           "python tutorial for beginners full",
#           "python (programming language)",
#           "python basics",
#           "python course",
#           "python from scratch",
#           "python full course",
#           "python language",
#           "python programming",
#           "python programming language",
#           "python programming tutorial",
#           "getting started with python",
#           "learn python programming",
#           "web development",
#           "mosh hamedani",
#           "machine learning",
#           "python 2020"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python Full Course for Beginners",
#           "description": "Learn Python for AI, machine learning, and web development with this beginner-friendly course! \ud83d\ude80 Get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper?\n- Check out my Python mastery course: https://mosh.link/python-course\n- Subscribe for more awesome Python content: https://goo.gl/6PYaGF\n\n\ud83d\udd17 Related videos \nhttps://youtu.be/yVl_G-F7m8c?si=aoIiT6CyaRRfBsRM\n\n\ud83d\udc49 New version available Watch here: https://youtu.be/kqtD5dpn9C8\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Supplementary materials (spreadsheet): https://github.com/mosh-hamedani/python-supplementary-materials\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 My favorite Python books\n- Python Crash Course: https://amzn.to/2GqMdjG\n- Automate the Boring Stuff with Python: https://amzn.to/2N71d6S\n- A Smarter Way to Learn Python: https://amzn.to/2UZa6lE\n- Machine Learning for Absolute Beginners: https://amzn.to/2Gs0koL\n- Hands-on Machine Learning with scikit-learn and TensorFlow: https://amzn.to/2IdUuJy\n\n\ud83d\udcd6 TABLE OF CONTENT\n00:00:00 Introduction\n00:01:49 Installing Python 3\n00:06:10 Your First Python Program\n00:08:11 How Python Code Gets Executed \n00:11:24 How Long It Takes To Learn Python \n00:13:03 Variables\n00:18:21 Receiving Input\n00:22:16 Python Cheat Sheet\n00:22:46 Type Conversion\n00:29:31 Strings\n00:37:36 Formatted Strings\n00:40:50 String Methods\n00:48:33 Arithmetic Operations\n00:51:33 Operator Precedence\n00:55:04 Math Functions\n00:58:17 If Statements\n01:06:32 Logical Operators\n01:11:25 Comparison Operators\n01:16:17 Weight Converter Program \n01:20:43 While Loops\n01:24:07 Building a Guessing Game\n01:30:51 Building the Car Game\n01:41:48 For Loops\n01:47:46 Nested Loops\n01:55:50 Lists\n02:01:45 2D Lists\n02:05:11 My Complete Python Course \n02:06:00 List Methods\n02:13:25 Tuples\n02:15:34 Unpacking\n02:18:21 Dictionaries\n02:26:21 Emoji Converter\n02:30:31 Functions\n02:35:21 Parameters\n02:39:24 Keyword Arguments \n02:44:45 Return Statement\n02:48:55 Creating a Reusable Function \n02:53:42 Exceptions\n02:59:14 Comments\n03:01:46 Classes\n03:07:46 Constructors\n03:14:41 Inheritance\n03:19:33 Modules\n03:30:12 Packages\n03:36:22 Generating Random Values\n03:44:37 Working with Directories \n03:50:47 Pypi and Pip\n03:55:34 Project 1: Automation with Python\n04:10:22 Project 2: Machine Learning with Python \n04:58:37 Project 3: Building a Website with Django\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT6H14M7S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "true",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "48354194",
#         "likeCount": "1261382",
#         "favoriteCount": "0",
#         "commentCount": "62836"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "71Ddvl6rEgB7ihvNBPCvKIXIQUM",
#       "id": "2xZJk8Vaxvk",
#       "snippet": {
#         "publishedAt": "2026-07-20T06:41:41Z",
#         "channelId": "UCCrEpVALr901PP01fkVo58g",
#         "title": "If Code Works Don't Touch It !! #coding #programming #python #shorts",
#         "description": "\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\nWELCOME TO \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05  \n\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\n\nHi, I\u2019m Ali Aziz \u2014 Web Developer, Coder, Animation Creator\n\nWhat You\u2019ll Get:\n\u2022 Easy step-by-step coding tutorials\n\u2022 AI-powered projects and tools\n\u2022 Creative animations with real code\n\u2022 Real-world websites and practical builds\n\nWhat You\u2019ll Learn:\n\u2022 HTML, CSS, JavaScript (Frontend to basics of Full-Stack)\n\u2022 Modern responsive design\n\u2022 AI + coding integration\n\u2022 Interactive animations and creative coding\n\nWhy Join:\n\u2022 Clean tutorials with source code\n\u2022 Beginner to advanced learning\n\u2022 Fast tips and useful coding hacks\n\u2022 Build real, practical skills\n\nPerfect For:\nBeginners, students, developers, and AI enthusiasts\n\nSubscribe and start building real projects\n\nLearn \u2022 Build \u2022 Grow\n\n\ud83d\udcbc Business & Sponsorships:\n\n\ud83d\udce9 Email: aliaziz.shakir@gmail.com\n\n\nHashtags:\n\n#azizsyntax\n#azizcodex\n#coding \n#earning \n#javascript \n#python \n#html \n#css \n#developer \n#programming \n#tech \n#computer",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/2xZJk8Vaxvk/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "\ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05",
#         "tags": [
#           "html",
#           "css",
#           "python",
#           "coding",
#           "programming",
#           "developer",
#           "app development",
#           "azizcodex",
#           "codewithaziz",
#           "Zdak",
#           "Code Venture",
#           "Hardware Nf",
#           "Only Memes",
#           "pc",
#           "gaming",
#           "earning",
#           "kadz",
#           "snipzmemes",
#           "mrunknownxd",
#           "mrunknown",
#           "memedoggyz",
#           "tech",
#           "computer",
#           "tech explained",
#           "PC components explained",
#           "understand computers",
#           "explainer videos",
#           "gaming technology",
#           "coding for beginners",
#           "programming tutorial",
#           "web design"
#         ],
#         "categoryId": "28",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-US",
#         "localized": {
#           "title": "If Code Works Don't Touch It !! #coding #programming #python #shorts",
#           "description": "\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\nWELCOME TO \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05  \n\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\u2501\n\nHi, I\u2019m Ali Aziz \u2014 Web Developer, Coder, Animation Creator\n\nWhat You\u2019ll Get:\n\u2022 Easy step-by-step coding tutorials\n\u2022 AI-powered projects and tools\n\u2022 Creative animations with real code\n\u2022 Real-world websites and practical builds\n\nWhat You\u2019ll Learn:\n\u2022 HTML, CSS, JavaScript (Frontend to basics of Full-Stack)\n\u2022 Modern responsive design\n\u2022 AI + coding integration\n\u2022 Interactive animations and creative coding\n\nWhy Join:\n\u2022 Clean tutorials with source code\n\u2022 Beginner to advanced learning\n\u2022 Fast tips and useful coding hacks\n\u2022 Build real, practical skills\n\nPerfect For:\nBeginners, students, developers, and AI enthusiasts\n\nSubscribe and start building real projects\n\nLearn \u2022 Build \u2022 Grow\n\n\ud83d\udcbc Business & Sponsorships:\n\n\ud83d\udce9 Email: aliaziz.shakir@gmail.com\n\n\nHashtags:\n\n#azizsyntax\n#azizcodex\n#coding \n#earning \n#javascript \n#python \n#html \n#css \n#developer \n#programming \n#tech \n#computer"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT8S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "5737",
#         "favoriteCount": "0",
#         "commentCount": "15"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "MIUvDxPKeb7QoKDho2gILfeziZE",
#       "id": "q2-pnQffZik",
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Learn Python for FREE in 2025",
#           "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT22S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1238282",
#         "likeCount": "30231",
#         "favoriteCount": "0",
#         "commentCount": "232"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "_pfHs6WFlk65leZ11MqGQoo9Hck",
#       "id": "80yIVH2aOy0",
#       "snippet": {
#         "publishedAt": "2025-06-06T00:51:25Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "python programming|python for beginners|python full course",
#         "description": "python programming|python for beginners|python full course\n\n\ud83d\udc49@monuinstitute\npython tutorial, learn python, python basics, python projects, machine learning, coder, python zero to hero, python for data, coding with python, python concepts, computer programming, learning python, coding python, data science python, python project ideas, python course, python coding, computers, python programming basics, how to learn python fast, beginner python, python syllabus, software engineer, python for kids, coding for kids, advanced python, data analysis\n\n\ud83d\udc49 Hashtags:\n#python #coding #pythonlanguage #pythonprogramming #codewithharry #apnacollege #pythontutorial #tutorial #turtle #cod #java #shorts #computer #cs",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/80yIVH2aOy0/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "tags": [
#           "advanced python",
#           "beginner python",
#           "coder",
#           "coding for kids",
#           "coding python",
#           "coding with python",
#           "computer programming",
#           "computers",
#           "data analysis",
#           "data science python",
#           "how to learn python fast",
#           "learn python",
#           "learning python",
#           "machine learning",
#           "python basics",
#           "python coding",
#           "python concepts",
#           "python course",
#           "python for data",
#           "python for kids",
#           "python programming basics",
#           "python project ideas",
#           "python projects",
#           "python syllabus",
#           "python tutorial",
#           "python zero to hero",
#           "software engineer"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-IN",
#         "localized": {
#           "title": "python programming|python for beginners|python full course",
#           "description": "python programming|python for beginners|python full course\n\n\ud83d\udc49@monuinstitute\npython tutorial, learn python, python basics, python projects, machine learning, coder, python zero to hero, python for data, coding with python, python concepts, computer programming, learning python, coding python, data science python, python project ideas, python course, python coding, computers, python programming basics, how to learn python fast, beginner python, python syllabus, software engineer, python for kids, coding for kids, advanced python, data analysis\n\n\ud83d\udc49 Hashtags:\n#python #coding #pythonlanguage #pythonprogramming #codewithharry #apnacollege #pythontutorial #tutorial #turtle #cod #java #shorts #computer #cs"
#         },
#         "defaultAudioLanguage": "hi"
#       },
#       "contentDetails": {
#         "duration": "PT11S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1595645",
#         "likeCount": "25690",
#         "favoriteCount": "0",
#         "commentCount": "232"
#       }
#     }
#   ],
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# **Channels API ENDPOINT**

# %%
CHANNELS_URL = "https://www.googleapis.com/youtube/v3/channels"

# %%
channel_ids = []

for item in video_data["items"]:
    channel_ids.append(item["snippet"]["channelId"])

print(channel_ids)
# Out:
# ['UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCCrEpVALr901PP01fkVo58g', 'UC7zZ2-Q_oxbUaoMVL0z51wg', 'UCMUuCs6Y1WzDpAKg_2W-3yA']

# %%
channel_ids = list(set(channel_ids))

print(channel_ids)
# Out:
# ['UCMUuCs6Y1WzDpAKg_2W-3yA', 'UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCCrEpVALr901PP01fkVo58g', 'UC7zZ2-Q_oxbUaoMVL0z51wg']

# %%
channel_ids = ",".join(channel_ids)

print(channel_ids)
# Out:
# UCMUuCs6Y1WzDpAKg_2W-3yA,UCWv7vMbMWH4-V0ZXdmDpPBA,UCCrEpVALr901PP01fkVo58g,UC7zZ2-Q_oxbUaoMVL0z51wg

# %%
channel_params = {
    "part": "snippet,statistics",
    "id": channel_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %%
channel_response = requests.get(CHANNELS_URL, params=channel_params)
print(channel_response.status_code)
# Out:
# 200

# %%
channel_data = channel_response.json()

# %%
print(json.dumps(channel_data, indent = 2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "3zmLCLueIr8vL5JIcJbdYXi6RYU",
#   "pageInfo": {
#     "totalResults": 4,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#channel",
#       "etag": "znQUawl2bkjRmb3BCYsVitLNVG0",
#       "id": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#       "snippet": {
#         "title": "Sajjaad Khader",
#         "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n",
#         "customUrl": "@sajjaadkhader",
#         "publishedAt": "2020-06-18T00:50:20.154391Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Sajjaad Khader",
#           "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "61170216",
#         "subscriberCount": "323000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "1320"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "ndzjw7-Yn64gRRNWK0meKFXzbbk",
#       "id": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#       "snippet": {
#         "title": "Programming with Mosh",
#         "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n",
#         "customUrl": "@programmingwithmosh",
#         "publishedAt": "2014-10-07T00:40:53Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Programming with Mosh",
#           "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "275288811",
#         "subscriberCount": "5110000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "246"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "Pjb4dseXL6EQuyNc8VP-BQRudCU",
#       "id": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#       "snippet": {
#         "title": "Monu institute ",
#         "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906",
#         "customUrl": "@monuinstitute",
#         "publishedAt": "2024-12-15T14:37:58.113164Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Monu institute ",
#           "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906"
#         },
#         "country": "IN"
#       },
#       "statistics": {
#         "viewCount": "8180849",
#         "subscriberCount": "8940",
#         "hiddenSubscriberCount": false,
#         "videoCount": "127"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "PYnSmmssvUif3374g151ueEU_Vw",
#       "id": "UCCrEpVALr901PP01fkVo58g",
#       "snippet": {
#         "title": "\ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05",
#         "description": "\ud83d\udd39 \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05 \ud83d\udd39\n\nLearn \u2022 Build \u2022 Grow\n\nWelcome to \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05. created by Ali Aziz \u2014 coding, computers, and technology made simple, practical, and powerful. Master HTML, CSS, JavaScript, Python, app development, AI tools, PC tips, and the latest tech with real-world projects.\n\n\u2554\u2550\u2566\u2557\u2554\u2566\u2557\u2554\u2550\u2566\u2550\u2566\u2566\u2566\u2566\u2557\u2554\u2550\u2557\n\u2551\u255a\u2563\u2551\u2551\u2551\u255a\u2563\u255a\u2563\u2554\u2563\u2554\u2563\u2551\u255a\u2563\u2550\n\u2560\u2557\u2551\u255a\u255d\u2551\u2551\u2560\u2557\u2551\u255a\u2563\u2551\u2551\u2551\u2551\u2551\u2550\n\u255a\u2550\u2569\u2550\u2550\u2569\u2550\u2569\u2550\u2569\u2550\u2569\u255d\u255a\u2569\u2550\u2569\u2550\u255d\n\nFOR (100K SUBSCRIBERS) !!\n------------------------------------------------\n\n *Business & Sponsorships* :\n\nIF you have any problems Regarding this YouTube channel than you can Contact.\nCollaborating with tech companies, startups, and educational brands.\n\ud83d\udce9 aliaziz.shakir@gmail.com\n\n",
#         "customUrl": "@azizcodex",
#         "publishedAt": "2025-09-03T12:59:39.799347Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/bnya9aHrnxOWmLZoVY3oD_uhCwxvrlBXgczgm4zIR_rsuPkZmI8pc7ggWrnAZ9sfKiCNO_O-eA=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/bnya9aHrnxOWmLZoVY3oD_uhCwxvrlBXgczgm4zIR_rsuPkZmI8pc7ggWrnAZ9sfKiCNO_O-eA=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/bnya9aHrnxOWmLZoVY3oD_uhCwxvrlBXgczgm4zIR_rsuPkZmI8pc7ggWrnAZ9sfKiCNO_O-eA=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "\ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05",
#           "description": "\ud83d\udd39 \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05 \ud83d\udd39\n\nLearn \u2022 Build \u2022 Grow\n\nWelcome to \ud835\uddd4\ud835\ude07\ud835\uddf6\ud835\ude07 \ud835\uddd6\ud835\uddfc\ud835\uddf1\ud835\uddf2\ud835\ude05. created by Ali Aziz \u2014 coding, computers, and technology made simple, practical, and powerful. Master HTML, CSS, JavaScript, Python, app development, AI tools, PC tips, and the latest tech with real-world projects.\n\n\u2554\u2550\u2566\u2557\u2554\u2566\u2557\u2554\u2550\u2566\u2550\u2566\u2566\u2566\u2566\u2557\u2554\u2550\u2557\n\u2551\u255a\u2563\u2551\u2551\u2551\u255a\u2563\u255a\u2563\u2554\u2563\u2554\u2563\u2551\u255a\u2563\u2550\n\u2560\u2557\u2551\u255a\u255d\u2551\u2551\u2560\u2557\u2551\u255a\u2563\u2551\u2551\u2551\u2551\u2551\u2550\n\u255a\u2550\u2569\u2550\u2550\u2569\u2550\u2569\u2550\u2569\u2550\u2569\u255d\u255a\u2569\u2550\u2569\u2550\u255d\n\nFOR (100K SUBSCRIBERS) !!\n------------------------------------------------\n\n *Business & Sponsorships* :\n\nIF you have any problems Regarding this YouTube channel than you can Contact.\nCollaborating with tech companies, startups, and educational brands.\n\ud83d\udce9 aliaziz.shakir@gmail.com\n\n"
#         },
#         "country": "PK"
#       },
#       "statistics": {
#         "viewCount": "72970111",
#         "subscriberCount": "28600",
#         "hiddenSubscriberCount": false,
#         "videoCount": "445"
#       }
#     }
#   ]
# }
