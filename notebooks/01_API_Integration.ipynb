# %% [markdown]
# **Imports**

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# **Configuration**

# %%
from dotenv import load_dotenv
import os

# Load variables from .env
load_dotenv()

# Read the API key
API_KEY = os.getenv("YOUTUBE_API_KEY")

if not API_KEY:
    raise ValueError("YOUTUBE_API_KEY not found in .env file")

SEARCH_URL = "https://www.googleapis.com/youtube/v3/search"

# %% [markdown]
# **Parameters**

# %%
params = {
    "part": "snippet",
    "q": "Python Programming",
    "type": "video",
    "maxResults": 5,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **API Request**

# %%
response = requests.get(SEARCH_URL, params=params)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# **Convert to JSON**

# %%
data = response.json()

# %% [markdown]
# **Inspect JSON**

# %%
print(json.dumps(data, indent = 2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "s9K2JFMxut9zWifNEv0bynC8qXo",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "IN",
#   "pageInfo": {
#     "totalResults": 471059,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "8a7GjkSL6bmqUPz2_aHW0wObfzM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kqtD5dpn9C8"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-16T13:00:20Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "ALaQyozfZ-ky8b74UcpItcqWUeA",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "q2-pnQffZik"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp Source: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-31T02:30:33Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "sft0O8daguSzigE5C4o_LppZlxs",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "xAcTmDO6NTI"
#       },
#       "snippet": {
#         "publishedAt": "2024-04-11T14:01:57Z",
#         "channelId": "UCEBb1b_L6zDS3xTUrIALZOw",
#         "title": "Lecture 1: Introduction to CS and Programming Using Python",
#         "description": "MIT 6.100L Introduction to CS and Programming using Python, Fall 2022 Instructor: Ana Bell View the complete course: ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "MIT OpenCourseWare",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-04-11T14:01:57Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Zv6GlZT0UA_uATA9CFostwMyiAc",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "DInMru2Eq6E"
#       },
#       "snippet": {
#         "publishedAt": "2022-08-26T14:30:02Z",
#         "channelId": "UCM-yUTYGmrNvKOCcAl21g3w",
#         "title": "Introduction to Python Programming | Python for Beginners #lec1",
#         "description": "Jenny's Lectures Mastering DSA with Java course(New Batch): ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Jenny's Lectures CS IT",
#         "liveBroadcastContent": "none",
#         "publishTime": "2022-08-26T14:30:02Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Nzo8Ch18Mn213UVPaSsfcSyanF0",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "GfWRxr1OBm4"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-29T01:57:30Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#         "description": "Python Basics: The Best Way to Learn Python Programming (2024) @monuinstitute Some of you asked me about Python ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-29T01:57:30Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# **Videos API ENDPOINT**

# %%
VIDEOS_URL = "https://www.googleapis.com/youtube/v3/videos"

# %% [markdown]
# **EXTRACT VIDEO IDS**

# %%
video_ids = []
for item in data["items"]:
    video_ids.append(item["id"]["videoId"])

print(video_ids)
# Out:
# ['kqtD5dpn9C8', 'q2-pnQffZik', 'xAcTmDO6NTI', 'DInMru2Eq6E', 'GfWRxr1OBm4']

# %%
video_ids = ",".join(video_ids)
print(video_ids)
# Out:
# kqtD5dpn9C8,q2-pnQffZik,xAcTmDO6NTI,DInMru2Eq6E,GfWRxr1OBm4

# %% [markdown]
# **VIDEOS API PARAMETERS**

# %%
video_params = {
    "part": "snippet,statistics,contentDetails",
    "id": video_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **Call Videos API**

# %%
video_response = requests.get(VIDEOS_URL, params=video_params)
print(video_response.status_code)
# Out:
# 200

# %%
video_data = video_response.json()

# %%
print(json.dumps(video_data, indent = 2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "km7-NZUTN_SYixd8s24SaawW5hU",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "sMOTem9JLwO_msSYkbGuaznF3bY",
#       "id": "kqtD5dpn9C8",
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "code with mosh",
#           "introduction to python",
#           "learn python",
#           "learn python programming",
#           "mosh hamedani",
#           "programming",
#           "programming with mosh",
#           "python",
#           "python 2020",
#           "python 3",
#           "python basics",
#           "python course",
#           "python crash course",
#           "python for beginners",
#           "python from scratch",
#           "python programming",
#           "python tutorial",
#           "python tutorial for beginners",
#           "web development"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#           "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT1H6S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "24742216",
#         "likeCount": "560729",
#         "favoriteCount": "0",
#         "commentCount": "28236"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "BG1Tvxf34XD-4414h20N-dOqIUw",
#       "id": "q2-pnQffZik",
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Learn Python for FREE in 2025",
#           "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT22S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1240183",
#         "likeCount": "30269",
#         "favoriteCount": "0",
#         "commentCount": "233"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "mr250amJ29w1cV9Qc9aiIMWnzAI",
#       "id": "xAcTmDO6NTI",
#       "snippet": {
#         "publishedAt": "2024-04-11T14:01:57Z",
#         "channelId": "UCEBb1b_L6zDS3xTUrIALZOw",
#         "title": "Lecture 1: Introduction to CS and Programming Using Python",
#         "description": "MIT 6.100L Introduction to CS and Programming using Python, Fall 2022\nInstructor: Ana Bell\n\nView the complete course: https://ocw.mit.edu/courses/6-100l-introduction-to-cs-and-programming-using-python-fall-2022/\nYouTube Playlist: https://www.youtube.com/playlist?list=PLUl4u3cNGP62A-ynp6v6-LGBCzeH3VAQB\n\nAn introduction to what computation is, python basics, mathematical operations, and python variables and types. We explore python objects and python programs.\n\nLicense: Creative Commons BY-NC-SA\nMore information at https://ocw.mit.edu/terms\nMore courses at https://ocw.mit.edu\nSupport OCW at http://ow.ly/a1If50zVRlQ\n\nWe encourage constructive comments and discussion on OCW\u2019s YouTube and other social media channels. Personal attacks, hate speech, trolling, and inappropriate comments are not allowed and may be removed. More details at https://ocw.mit.edu/comments.",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/xAcTmDO6NTI/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "MIT OpenCourseWare",
#         "tags": [
#           "6-100l-introduction-to-cs-and-programming-using-python-fall-2022",
#           "computational thinking",
#           "computer science",
#           "introductory programming",
#           "python",
#           "python variables"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-US",
#         "localized": {
#           "title": "Lecture 1: Introduction to CS and Programming Using Python",
#           "description": "MIT 6.100L Introduction to CS and Programming using Python, Fall 2022\nInstructor: Ana Bell\n\nView the complete course: https://ocw.mit.edu/courses/6-100l-introduction-to-cs-and-programming-using-python-fall-2022/\nYouTube Playlist: https://www.youtube.com/playlist?list=PLUl4u3cNGP62A-ynp6v6-LGBCzeH3VAQB\n\nAn introduction to what computation is, python basics, mathematical operations, and python variables and types. We explore python objects and python programs.\n\nLicense: Creative Commons BY-NC-SA\nMore information at https://ocw.mit.edu/terms\nMore courses at https://ocw.mit.edu\nSupport OCW at http://ow.ly/a1If50zVRlQ\n\nWe encourage constructive comments and discussion on OCW\u2019s YouTube and other social media channels. Personal attacks, hate speech, trolling, and inappropriate comments are not allowed and may be removed. More details at https://ocw.mit.edu/comments."
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT1H3M30S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "true",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "2121952",
#         "likeCount": "46935",
#         "favoriteCount": "0",
#         "commentCount": "1075"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "8JdiWCptlGi0Vwj00mu4zvS1xSA",
#       "id": "DInMru2Eq6E",
#       "snippet": {
#         "publishedAt": "2022-08-26T14:30:02Z",
#         "channelId": "UCM-yUTYGmrNvKOCcAl21g3w",
#         "title": "Introduction to Python Programming | Python for Beginners #lec1",
#         "description": "\ud83d\udd25 Jenny's Lectures Mastering DSA with Java course(New Batch): \nhttps://www.jennyslectures.com/courses/Mastering-DSA-with-JAVA-2-68ce8b083425e77d71739441\n\n\u26a1 Limited seats! First 500 students get an extra 20% OFF with coupon: BEST500\n\nJenny's Lectures JAVA from Scratch Course: https://www.jennyslectures.com/courses/Java-From-Scratch-67c9a7244b2225248cf88385\n\nGenAI Course for beginners: https://www.jennyslectures.com/courses/Generative-AI-for-Beginners-From-Basics-to-Chatbot-Creation-68584c28a81c363f9f037df1\n\n\ud83d\udd25Notes of Today's Class: https://drive.google.com/file/d/1WjmeotoY7iwtYVe_W90j6k3a-pGoPCWQ/view?usp=sharing\n******************************************************\n\nConnect & Contact Me:\n\nFacebook: https://www.facebook.com/Jennys-Lectures-CSIT-Netjrf-316814368950701/\nInstagram: https://www.instagram.com/jayantikhatrilamba/\nTwitter: https://twitter.com/KhatriJenny\nLinkedIn: https://www.linkedin.com/in/jayanti-khatri-32653817/\n\n*******************************************************\nMore Playlists:\n\n\ud83d\udd25Python Tutorials for Beginners: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bZSiqiOL5ta39vSnBxpOPT\nC complete playlist: https://www.youtube.com/playlist?list=PLdo5W4Nhv31a8UcMN9-35ghv8qyFWD9_S\nC++ Complete Playlist: https://www.youtube.com/watch?v=KYxLEDF6kjs&list=PLdo5W4Nhv31YU5Wx1dopka58teWP9aCee\nPlacement Series: https://www.youtube.com/playlist?list=PLdo5W4Nhv31YvlDpJhvOYbM9Ap8UypgEy\nData Structures and Algorithms: https: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bbKJzrsKfMpo_grxuLl8LU\nDesign and Analysis of Algorithms(DAA): https://www.youtube.com/playlist?list=PLdo5W4Nhv31ZTn2P9vF02bkb3SC8uiUUn\nDynamic Programming: https://www.youtube.com/playlist?list=PLdo5W4Nhv31aBrJE1WS4MR9LRfbmZrAQu\nOperating Systems: //www.youtube.com/playlist?list=PLdo5W4Nhv31a5ucW_S1K3-x6ztBRD-PNa\nDBMS: https://www.youtube.com/playlist?list=PLdo5W4Nhv31b33kF46f9aFjoJPOkdlsRc\n#python #programming #jennyslectures",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/DInMru2Eq6E/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Jenny's Lectures CS IT",
#         "tags": [
#           "operating system",
#           "data structure and algorithms",
#           "jayanti khatri lamba",
#           "jennys lectures",
#           "jennys lectures baby",
#           "C++",
#           "C++ complete course",
#           "c++ placement course",
#           "gate cs lectures",
#           "ugc net computer science preparation",
#           "ugc net syllabus",
#           "c++ jennys lectures",
#           "object oriented programming in C++",
#           "introduction to python programming",
#           "python full course for beginners",
#           "python jennys lectures",
#           "java programming",
#           "best channel to learn programming",
#           "c programming"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Introduction to Python Programming | Python for Beginners #lec1",
#           "description": "\ud83d\udd25 Jenny's Lectures Mastering DSA with Java course(New Batch): \nhttps://www.jennyslectures.com/courses/Mastering-DSA-with-JAVA-2-68ce8b083425e77d71739441\n\n\u26a1 Limited seats! First 500 students get an extra 20% OFF with coupon: BEST500\n\nJenny's Lectures JAVA from Scratch Course: https://www.jennyslectures.com/courses/Java-From-Scratch-67c9a7244b2225248cf88385\n\nGenAI Course for beginners: https://www.jennyslectures.com/courses/Generative-AI-for-Beginners-From-Basics-to-Chatbot-Creation-68584c28a81c363f9f037df1\n\n\ud83d\udd25Notes of Today's Class: https://drive.google.com/file/d/1WjmeotoY7iwtYVe_W90j6k3a-pGoPCWQ/view?usp=sharing\n******************************************************\n\nConnect & Contact Me:\n\nFacebook: https://www.facebook.com/Jennys-Lectures-CSIT-Netjrf-316814368950701/\nInstagram: https://www.instagram.com/jayantikhatrilamba/\nTwitter: https://twitter.com/KhatriJenny\nLinkedIn: https://www.linkedin.com/in/jayanti-khatri-32653817/\n\n*******************************************************\nMore Playlists:\n\n\ud83d\udd25Python Tutorials for Beginners: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bZSiqiOL5ta39vSnBxpOPT\nC complete playlist: https://www.youtube.com/playlist?list=PLdo5W4Nhv31a8UcMN9-35ghv8qyFWD9_S\nC++ Complete Playlist: https://www.youtube.com/watch?v=KYxLEDF6kjs&list=PLdo5W4Nhv31YU5Wx1dopka58teWP9aCee\nPlacement Series: https://www.youtube.com/playlist?list=PLdo5W4Nhv31YvlDpJhvOYbM9Ap8UypgEy\nData Structures and Algorithms: https: https://www.youtube.com/playlist?list=PLdo5W4Nhv31bbKJzrsKfMpo_grxuLl8LU\nDesign and Analysis of Algorithms(DAA): https://www.youtube.com/playlist?list=PLdo5W4Nhv31ZTn2P9vF02bkb3SC8uiUUn\nDynamic Programming: https://www.youtube.com/playlist?list=PLdo5W4Nhv31aBrJE1WS4MR9LRfbmZrAQu\nOperating Systems: //www.youtube.com/playlist?list=PLdo5W4Nhv31a5ucW_S1K3-x6ztBRD-PNa\nDBMS: https://www.youtube.com/playlist?list=PLdo5W4Nhv31b33kF46f9aFjoJPOkdlsRc\n#python #programming #jennyslectures"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT11M14S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1663868",
#         "likeCount": "28157",
#         "favoriteCount": "0",
#         "commentCount": "946"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "V7IOWKPzgDgEK0gxLWH5HckCRd8",
#       "id": "GfWRxr1OBm4",
#       "snippet": {
#         "publishedAt": "2024-12-29T01:57:30Z",
#         "channelId": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#         "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#         "description": "Python Basics: The Best Way to Learn Python Programming (2024)\n\ud83d\udc49@monuinstitute\n\nSome of you asked me about Python courses for further learning. I strongly recommend you not to buy any overpriced course. One of the most underrated resources in the journey of programmers is Udemy (This post is not sponsored).\nThe affordable courses Udemy provides with doubt support are way way better than most of the paid courses I see online these days. Here are some of my top picks with discount applied for you:\nPython is one of the most demanded programming languages in the job market. Surprisingly, it is equally easy to learn and master  Python. This python tutorial for absolute beginners in Hindi series will focus on teaching you python concepts from the ground up. Today we will see some of the mindblowing python programs, I created.\n\nTopic:\n1) python coding \n2) python language \n3) python programming \n4) python course \n5) python import library \n6) python graphics \n7) python tutorial \n8) python import statement \n9) python project \n10) python complete course \n11)monu institute \n\nTags:\npython for beginners\npython projects\ndata science python\n python tutorial\n learn python\npython course\ncoding for beginners\npython tips\npython scripting\npython automation\ndata analysis\npython automation projects\nhow to learn python\n python programming\npython basics\nlearn python from scratch\n coding\npython tricks\nprogramming skills\npython tutorial for beginners\n python tutorials\n data analysis python\ncode\nprogramming\n advanced python\n python scripts\n\nHashtags:\n#python #coding #code #cod #pythonprogramming #computerscience #computerknowledge #computer #learning #learncoding #codelover #computers #education #educational #educational\n\nHello dosto video se sambandhit sujhav dene ke liye neech diye gye email sujhav de sakte hai\n\ud83d\udc49 E-mail: mv8293399@gmail.com",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/GfWRxr1OBm4/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Monu institute ",
#         "tags": [
#           "advanced python",
#           "code",
#           "coding",
#           "coding for beginners",
#           "data analysis",
#           "data analysis python",
#           "data science python",
#           "how to learn python",
#           "learn python",
#           "learn python from scratch",
#           "programming",
#           "programming skills",
#           "python automation",
#           "python automation projects",
#           "python basics",
#           "python course",
#           "python for beginners",
#           "python programming",
#           "python projects",
#           "python scripting",
#           "python scripts",
#           "python tips",
#           "python tricks",
#           "python tutorial",
#           "python tutorial for beginners",
#           "python tutorials"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en-IN",
#         "localized": {
#           "title": "Python Basics: The Best Way to Learn Python Programming (2024)",
#           "description": "Python Basics: The Best Way to Learn Python Programming (2024)\n\ud83d\udc49@monuinstitute\n\nSome of you asked me about Python courses for further learning. I strongly recommend you not to buy any overpriced course. One of the most underrated resources in the journey of programmers is Udemy (This post is not sponsored).\nThe affordable courses Udemy provides with doubt support are way way better than most of the paid courses I see online these days. Here are some of my top picks with discount applied for you:\nPython is one of the most demanded programming languages in the job market. Surprisingly, it is equally easy to learn and master  Python. This python tutorial for absolute beginners in Hindi series will focus on teaching you python concepts from the ground up. Today we will see some of the mindblowing python programs, I created.\n\nTopic:\n1) python coding \n2) python language \n3) python programming \n4) python course \n5) python import library \n6) python graphics \n7) python tutorial \n8) python import statement \n9) python project \n10) python complete course \n11)monu institute \n\nTags:\npython for beginners\npython projects\ndata science python\n python tutorial\n learn python\npython course\ncoding for beginners\npython tips\npython scripting\npython automation\ndata analysis\npython automation projects\nhow to learn python\n python programming\npython basics\nlearn python from scratch\n coding\npython tricks\nprogramming skills\npython tutorial for beginners\n python tutorials\n data analysis python\ncode\nprogramming\n advanced python\n python scripts\n\nHashtags:\n#python #coding #code #cod #pythonprogramming #computerscience #computerknowledge #computer #learning #learncoding #codelover #computers #education #educational #educational\n\nHello dosto video se sambandhit sujhav dene ke liye neech diye gye email sujhav de sakte hai\n\ud83d\udc49 E-mail: mv8293399@gmail.com"
#         },
#         "defaultAudioLanguage": "hi"
#       },
#       "contentDetails": {
#         "duration": "PT9S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "2780482",
#         "likeCount": "36265",
#         "favoriteCount": "0",
#         "commentCount": "299"
#       }
#     }
#   ],
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# **Channels API ENDPOINT**

# %%
CHANNELS_URL = "https://www.googleapis.com/youtube/v3/channels"

# %%
channel_ids = []

for item in video_data["items"]:
    channel_ids.append(item["snippet"]["channelId"])

print(channel_ids)
# Out:
# ['UCWv7vMbMWH4-V0ZXdmDpPBA', 'UC7zZ2-Q_oxbUaoMVL0z51wg', 'UCEBb1b_L6zDS3xTUrIALZOw', 'UCM-yUTYGmrNvKOCcAl21g3w', 'UCMUuCs6Y1WzDpAKg_2W-3yA']

# %%
channel_ids = list(set(channel_ids))

print(channel_ids)
# Out:
# ['UC7zZ2-Q_oxbUaoMVL0z51wg', 'UCMUuCs6Y1WzDpAKg_2W-3yA', 'UCEBb1b_L6zDS3xTUrIALZOw', 'UCM-yUTYGmrNvKOCcAl21g3w', 'UCWv7vMbMWH4-V0ZXdmDpPBA']

# %%
channel_ids = ",".join(channel_ids)

print(channel_ids)
# Out:
# UC7zZ2-Q_oxbUaoMVL0z51wg,UCMUuCs6Y1WzDpAKg_2W-3yA,UCEBb1b_L6zDS3xTUrIALZOw,UCM-yUTYGmrNvKOCcAl21g3w,UCWv7vMbMWH4-V0ZXdmDpPBA

# %%
channel_params = {
    "part": "snippet,statistics",
    "id": channel_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %%
channel_response = requests.get(CHANNELS_URL, params=channel_params)
print(channel_response.status_code)
# Out:
# 200

# %%
channel_data = channel_response.json()

# %%
print(json.dumps(channel_data, indent = 2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "Pjt8tgsEYh1bcAE3dsALarQiZRU",
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#channel",
#       "etag": "Lo2GC2wi85x7CehDAPnB_bGDa8E",
#       "id": "UCM-yUTYGmrNvKOCcAl21g3w",
#       "snippet": {
#         "title": "Jenny's Lectures CS IT",
#         "description": "Warm Welcome to Jenny's Lectures. On This Channel we are focusing on creating tutorials for  engineers, software developers, programmers, Coders, undergraduates, graduates. We cover topics for all different skill levels, so whether you are a beginner or have some years of experience, this channel will have something for you.\n\nWe've already uploaded a wide variety of videos on topics that include: JAVA,C, C++, Python, Computer Science Fundamentals, Computer Science subjects like OS, DBMS, Data Structures, DSA, DAA, Placement Series, GATE Coaching Videos, UGC NET syllabus Videos and plenty of other tips and tricks which will help you in your career.\n\n",
#         "customUrl": "@jennyslecturescsit",
#         "publishedAt": "2019-01-19T18:46:22Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/G_0IAqOglBkQz1-AFWsxxiRrT7DjPfrQksCMs-I82D6wCOrG1PCa9LjntW9zW5TodRLccBr6ew=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Jenny's Lectures CS IT",
#           "description": "Warm Welcome to Jenny's Lectures. On This Channel we are focusing on creating tutorials for  engineers, software developers, programmers, Coders, undergraduates, graduates. We cover topics for all different skill levels, so whether you are a beginner or have some years of experience, this channel will have something for you.\n\nWe've already uploaded a wide variety of videos on topics that include: JAVA,C, C++, Python, Computer Science Fundamentals, Computer Science subjects like OS, DBMS, Data Structures, DSA, DAA, Placement Series, GATE Coaching Videos, UGC NET syllabus Videos and plenty of other tips and tricks which will help you in your career.\n\n"
#         },
#         "country": "IN"
#       },
#       "statistics": {
#         "viewCount": "293858795",
#         "subscriberCount": "2090000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "930"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "R1S2M-0D7mDbjuAcZF5Y5Nrw6ls",
#       "id": "UCEBb1b_L6zDS3xTUrIALZOw",
#       "snippet": {
#         "title": "MIT OpenCourseWare",
#         "description": "A free and open online publication of educational material from thousands of MIT courses, covering the entire MIT curriculum, ranging from introductory to the most advanced graduate courses. On the OCW website, each course includes a syllabus, instructional material like notes and reading lists, and learning activities like assignments and solutions. Some courses also have videos, online textbooks, and faculty insights on teaching.\n\nKnowledge is your reward. There's no signup or enrollment, and no start or end dates. OCW is self-paced learning at its best. \n\nWhether you\u2019re a student, a teacher, or simply a curious person that wants to learn, MIT OpenCourseWare (OCW) offers a wealth of insight, inspiration, videos, and a whole lot more! \n\nGet the full picture on the OCW website at https://ocw.mit.edu.\n\nAccessibility: https://accessibility.mit.edu/ \n\nUser comments policy:  https://ocw.mit.edu/comments/\n\n(Channel banner photo by Nietnagel on Flickr: https://flic.kr/p/8WXxfK.)",
#         "customUrl": "@mitocw",
#         "publishedAt": "2005-10-11T09:36:14Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/swNtJDBP8xHP_zwrbL4tCUQt02B-7Mr8XggFMBjANHn_Q5aUtPmxPs8f8Ag3wO2O-rJpsQQGpA=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/swNtJDBP8xHP_zwrbL4tCUQt02B-7Mr8XggFMBjANHn_Q5aUtPmxPs8f8Ag3wO2O-rJpsQQGpA=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/swNtJDBP8xHP_zwrbL4tCUQt02B-7Mr8XggFMBjANHn_Q5aUtPmxPs8f8Ag3wO2O-rJpsQQGpA=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "MIT OpenCourseWare",
#           "description": "A free and open online publication of educational material from thousands of MIT courses, covering the entire MIT curriculum, ranging from introductory to the most advanced graduate courses. On the OCW website, each course includes a syllabus, instructional material like notes and reading lists, and learning activities like assignments and solutions. Some courses also have videos, online textbooks, and faculty insights on teaching.\n\nKnowledge is your reward. There's no signup or enrollment, and no start or end dates. OCW is self-paced learning at its best. \n\nWhether you\u2019re a student, a teacher, or simply a curious person that wants to learn, MIT OpenCourseWare (OCW) offers a wealth of insight, inspiration, videos, and a whole lot more! \n\nGet the full picture on the OCW website at https://ocw.mit.edu.\n\nAccessibility: https://accessibility.mit.edu/ \n\nUser comments policy:  https://ocw.mit.edu/comments/\n\n(Channel banner photo by Nietnagel on Flickr: https://flic.kr/p/8WXxfK.)"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "541209951",
#         "subscriberCount": "6400000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "8114"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "p2qUHlXm3_n4ylEt0L4twwCPD40",
#       "id": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#       "snippet": {
#         "title": "Sajjaad Khader",
#         "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n",
#         "customUrl": "@sajjaadkhader",
#         "publishedAt": "2020-06-18T00:50:20.154391Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Sajjaad Khader",
#           "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "61209740",
#         "subscriberCount": "323000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "1320"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "jyPjnZ-9goEef9vQSd96NOSpMIE",
#       "id": "UCMUuCs6Y1WzDpAKg_2W-3yA",
#       "snippet": {
#         "title": "Monu institute ",
#         "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906",
#         "customUrl": "@monuinstitute",
#         "publishedAt": "2024-12-15T14:37:58.113164Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/3-PTQjaW3LCMGqCx6s2nYqgqfvsThWDZ-o8pcYwxV1gpu0rIfj_0dymOssAMCl-IOMVKxGXv=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Monu institute ",
#           "description": "\nHello dosto Mai aapko is channel per computer se sambndhit complete video provide Kara Raha hu \n\nComputer se sambandhin kisi bhi course ka video yaha per complete milega \nEx- O level, CCC, PGDCA, ADCA, DCAA, DCA, DOAP BCA, etc \n\nYaha aapko  computer competition exam se sambandhit bhi video provide karaya jayega\n\n\ud83d\udc49\u0926\u094b\u0938\u094d\u0924\u094b\u0902 \u0907\u0938 \u091f\u0947\u0932\u0940\u0917\u094d\u0930\u093e\u092e \u091a\u0948\u0928\u0932 \u092a\u0930 \u0915\u092e\u094d\u092a\u0932\u0940\u091f \u0915\u094b\u0921 \u0915\u093e PDF \u092a\u094d\u0930\u094b\u0935\u093e\u0907\u0921 \u0915\u093f\u092f\u093e \u091c\u093e\u090f\u0917\u093e \n( Friends, PDF of complete code will be provided on this telegram channel )\n\nLinks:- https://t.me/Monuinstitute\nTeligram Search for id:- @Monuinstitute\n\nEmail Id:- monuinstitute2001@gmail.com\nFacebook account:- https://www.facebook.com/profile.php?id=61580090738906"
#         },
#         "country": "IN"
#       },
#       "statistics": {
#         "viewCount": "8198073",
#         "subscriberCount": "8960",
#         "hiddenSubscriberCount": false,
#         "videoCount": "127"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "NxtC1RXe6qMtb1M2jXn7AoEdsI8",
#       "id": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#       "snippet": {
#         "title": "Programming with Mosh",
#         "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n",
#         "customUrl": "@programmingwithmosh",
#         "publishedAt": "2014-10-07T00:40:53Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Programming with Mosh",
#           "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "275352417",
#         "subscriberCount": "5110000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "246"
#       }
#     }
#   ]
# }
