# %% [markdown]
# **Imports**

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# **Configuration**

# %%
API_KEY = "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
SEARCH_URL = "https://www.googleapis.com/youtube/v3/search"

# %% [markdown]
# **Parameters**

# %%
params = {
    "part": "snippet",
    "q": "Python Programming",
    "type": "video",
    "maxResults": 5,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **API Request**

# %%
response = requests.get(SEARCH_URL, params=params)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# **Convert to JSON**

# %%
data = response.json()

# %% [markdown]
# **Inspect JSON**

# %%
print(json.dumps(data, indent = 2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "h5jkxOd5Bl7wH9TJhCSDsHxQx7g",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "US",
#   "pageInfo": {
#     "totalResults": 1000000,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "8a7GjkSL6bmqUPz2_aHW0wObfzM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kqtD5dpn9C8"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-16T13:00:20Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "omansXP1JMbWLZPcYAMI2wag_iE",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "K5KVEU3aaeQ"
#       },
#       "snippet": {
#         "publishedAt": "2025-02-12T12:30:31Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Master Python from scratch No fluff\u2014just clear, practical coding skills to kickstart your journey! Want to dive deeper? - Check ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "liveBroadcastContent": "none",
#         "publishTime": "2025-02-12T12:30:31Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "ALaQyozfZ-ky8b74UcpItcqWUeA",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "q2-pnQffZik"
#       },
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp Source: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-12-31T02:30:33Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "C9upqF_PcCjCgeumvI9RUocmReA",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "F2Mx-u7auUs"
#       },
#       "snippet": {
#         "publishedAt": "2022-11-29T01:00:04Z",
#         "channelId": "UCJIfeSCssxSC_Dhc5s7woww",
#         "title": "How to learn Python programming | Guido van Rossum and Lex Fridman",
#         "description": "Lex Fridman Podcast full episode: https://www.youtube.com/watch?v=-DVyjdw4t9I Please support this podcast by checking out ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "Lex Clips",
#         "liveBroadcastContent": "none",
#         "publishTime": "2022-11-29T01:00:04Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "gD2UFQyJsxhoty5V5FSKguvP6Ck",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "nluUYtejoIE"
#       },
#       "snippet": {
#         "publishedAt": "2024-06-21T07:55:33Z",
#         "channelId": "UCAy1PN6jrZXrGFg79WP_91A",
#         "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#         "description": "In this quick tutorial, I'll show you how to write your very first line of Python code: the classic \"Hello, World!\" \u2728 Whether you're a ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "The Programmers Realm",
#         "liveBroadcastContent": "none",
#         "publishTime": "2024-06-21T07:55:33Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# **Videos API ENDPOINT**

# %%
VIDEOS_URL = "https://www.googleapis.com/youtube/v3/videos"

# %% [markdown]
# **EXTRACT VIDEO IDS**

# %%
video_ids = []
for item in data["items"]:
    video_ids.append(item["id"]["videoId"])

print(video_ids)
# Out:
# ['kqtD5dpn9C8', 'K5KVEU3aaeQ', 'q2-pnQffZik', 'F2Mx-u7auUs', 'nluUYtejoIE']

# %%
video_ids = ",".join(video_ids)
print(video_ids)
# Out:
# kqtD5dpn9C8,K5KVEU3aaeQ,q2-pnQffZik,F2Mx-u7auUs,nluUYtejoIE

# %% [markdown]
# **VIDEOS API PARAMETERS**

# %%
video_params = {
    "part": "snippet,statistics,contentDetails",
    "id": video_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %% [markdown]
# **Call Videos API**

# %%
video_response = requests.get(VIDEOS_URL, params=video_params)
print(video_response.status_code)
# Out:
# 200

# %%
video_data = video_response.json()

# %%
print(json.dumps(video_data, indent = 2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "1BGfXSvrYLCzA3az5jBBgHCyMOA",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "DOgogRALs7e3eg5QQ_XZBWhyn4E",
#       "id": "kqtD5dpn9C8",
#       "snippet": {
#         "publishedAt": "2020-09-16T13:00:20Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#         "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/kqtD5dpn9C8/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "code with mosh",
#           "introduction to python",
#           "learn python",
#           "learn python programming",
#           "mosh hamedani",
#           "programming",
#           "programming with mosh",
#           "python",
#           "python 2020",
#           "python 3",
#           "python basics",
#           "python course",
#           "python crash course",
#           "python for beginners",
#           "python from scratch",
#           "python programming",
#           "python tutorial",
#           "python tutorial for beginners",
#           "web development"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python for Beginners - Learn Coding with Python in 1 Hour",
#           "description": "Learn Python basics in just 1 hour! Perfect for beginners interested in AI and coding. \u26a1 Plus, get 6 months of PyCharm FREE with the coupon in the description!\n\n\ud83d\ude80 Want to dive deeper? Check out my Complete Python Mastery course: \n- Full course: https://mosh.link/python-course\n- Subscribe for more Python tutorials like this: https://goo.gl/6PYaGF\n\n\ud83d\udcd5 Get the FREE goodies:\n- Python cheat sheet: https://mosh.link/python-cheatsheet\n- Get 6 months of PyCharm for free with this coupon code: MOSH_YOUTUBE - Redeem it at: https://jb.gg/redeem\n\n\u270b Stay connected:\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\u2b50 Related tutorials\nhttps://youtu.be/yVl_G-F7m8c?si=11emtFyDccTKCGn7\n\n\ud83d\udcd6 TABLE OF CONTENT\n0:00:00 Introduction \n0:00:30 What You Can Do With Python \n0:01:15 Your First Python Program \n0:05:30 Variables\n0:09:08 Receiving Input\n0:10:48 Type Conversion\n0:18:49 Strings\n0:23:41 Arithmetic Operators \n0:25:59 Operator Precedence \n0:27:11 Comparison Operators \n0:28:52 Logical Operators\n0:31:06 If Statements\n0:36:16 Exercise\n0:41:42 While Loops\n0:45:11 Lists\n0:48:47 List Methods\n0:52:16 For Loops\n0:54:54 The range() Function \n0:57:43 Tuples\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT1H6S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "24726213",
#         "likeCount": "560485",
#         "favoriteCount": "0",
#         "commentCount": "28227"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "V1IPpEhza3Ea_clrPkroVjc0nM4",
#       "id": "K5KVEU3aaeQ",
#       "snippet": {
#         "publishedAt": "2025-02-12T12:30:31Z",
#         "channelId": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#         "title": "Python Full Course for Beginners",
#         "description": "Master Python from scratch \ud83d\ude80 No fluff\u2014just clear, practical coding skills to kickstart your journey! \n\n\ud83d\ude80 Want to dive deeper?\n- Check out my complete Python mastery course: https://mosh.link/python-course\n- Subscribe for more awesome Python content: https://goo.gl/6PYaGF\n\n\ud83d\udd17 Related videos \nhttps://youtu.be/yVl_G-F7m8c?si=aoIiT6CyaRRfBsRM\n\n\u270b Stay connected:\n- Full Courses: https://codewithmosh.com\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\ud83d\udcd6 Table of Content\n0:00:00 Introduction\n0:00:56 What is Python?\n0:04:11 Installing Python\n0:05:36 Python Interpreter\n0:07:30 Code Editors\n0:08:49 Your First Python Program\n0:12:25 Python Extension\n0:14:26 Linting Python Code\n0:18:40 Formatting Python Code\n0:22:51 Running Python Code\n0:24:30 Python Implementations\n0:26:59 How Python Code is Executed\n0:29:45 Quiz\n0:31:17 Python Mastery Course\n0:31:44 Variables\n0:34:48 Variable Names\n0:37:51 Strings\n0:43:20 Escape Sequences\n0:46:01 Formatted Strings\n0:48:09 String Methods\n0:54:03 Numbers\n0:56:50 Working With Numbers\n0:58:59 Type Conversion\n1:04:03 Quiz\n1:06:43 Comparison Operators\n1:08:46 Conditional Statements\n1:12:56 Ternary Operator\n1:15:04 Logical Operators\n1:19:07 Short-circuit Evaluations\n1:21:13 Chaining Comparison Operators\n1:22:35 Quiz\n1:24:18 For Loops\n1:27:56 For..Else\n1:30:42 Nested Loops\n1:33:26 Iterables\n1:36:34 While Loops\n1:41:33 Infinite Loops\n1:43:10 Exercise\n1:45:13 Defining Functions\n1:47:37 Arguments\n1:49:57 Types of Functions\n1:53:59 Keyword Arguments\n1:55:59 Default Arguments\n1:57:34 xargs\n\n#Python #AI #MachineLearning #WebDevelopment",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/K5KVEU3aaeQ/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Programming with Mosh",
#         "tags": [
#           "python full course",
#           "python full course for begginers",
#           "python beginners course",
#           "python complete course",
#           "python full tutorial",
#           "python tutorial",
#           "python programming tutorial",
#           "python tutorial for beginners",
#           "learn python",
#           "python basics",
#           "programming tutorial",
#           "python crash course",
#           "complete python course",
#           "python",
#           "python course",
#           "python programming",
#           "python for everybody",
#           "programming with mosh",
#           "mosh hamedani",
#           "code with mosh"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python Full Course for Beginners",
#           "description": "Master Python from scratch \ud83d\ude80 No fluff\u2014just clear, practical coding skills to kickstart your journey! \n\n\ud83d\ude80 Want to dive deeper?\n- Check out my complete Python mastery course: https://mosh.link/python-course\n- Subscribe for more awesome Python content: https://goo.gl/6PYaGF\n\n\ud83d\udd17 Related videos \nhttps://youtu.be/yVl_G-F7m8c?si=aoIiT6CyaRRfBsRM\n\n\u270b Stay connected:\n- Full Courses: https://codewithmosh.com\n- Twitter: https://twitter.com/moshhamedani\n- Facebook: https://www.facebook.com/programmingwithmosh/\n- Instagram: https://www.instagram.com/codewithmosh.official/\n- LinkedIn: https://www.linkedin.com/school/codewithmosh/\n\n\ud83d\udcd6 Table of Content\n0:00:00 Introduction\n0:00:56 What is Python?\n0:04:11 Installing Python\n0:05:36 Python Interpreter\n0:07:30 Code Editors\n0:08:49 Your First Python Program\n0:12:25 Python Extension\n0:14:26 Linting Python Code\n0:18:40 Formatting Python Code\n0:22:51 Running Python Code\n0:24:30 Python Implementations\n0:26:59 How Python Code is Executed\n0:29:45 Quiz\n0:31:17 Python Mastery Course\n0:31:44 Variables\n0:34:48 Variable Names\n0:37:51 Strings\n0:43:20 Escape Sequences\n0:46:01 Formatted Strings\n0:48:09 String Methods\n0:54:03 Numbers\n0:56:50 Working With Numbers\n0:58:59 Type Conversion\n1:04:03 Quiz\n1:06:43 Comparison Operators\n1:08:46 Conditional Statements\n1:12:56 Ternary Operator\n1:15:04 Logical Operators\n1:19:07 Short-circuit Evaluations\n1:21:13 Chaining Comparison Operators\n1:22:35 Quiz\n1:24:18 For Loops\n1:27:56 For..Else\n1:30:42 Nested Loops\n1:33:26 Iterables\n1:36:34 While Loops\n1:41:33 Infinite Loops\n1:43:10 Exercise\n1:45:13 Defining Functions\n1:47:37 Arguments\n1:49:57 Types of Functions\n1:53:59 Keyword Arguments\n1:55:59 Default Arguments\n1:57:34 xargs\n\n#Python #AI #MachineLearning #WebDevelopment"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT2H2M21S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "6955481",
#         "likeCount": "159125",
#         "favoriteCount": "0",
#         "commentCount": "4163"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "-ZlGPh18378UBbi7BvTuVMCC-V8",
#       "id": "q2-pnQffZik",
#       "snippet": {
#         "publishedAt": "2024-12-31T02:30:33Z",
#         "channelId": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#         "title": "Learn Python for FREE in 2025",
#         "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/q2-pnQffZik/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Sajjaad Khader",
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Learn Python for FREE in 2025",
#           "description": "Learn Python for FREE in 2025 #coding #compsci #python #fyp \n\n\nSource: TikTok (individualkex)"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT22S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1237677",
#         "likeCount": "30214",
#         "favoriteCount": "0",
#         "commentCount": "232"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "27R0FqivsB9P1jFi2J51jLXeCiI",
#       "id": "F2Mx-u7auUs",
#       "snippet": {
#         "publishedAt": "2022-11-29T01:00:04Z",
#         "channelId": "UCJIfeSCssxSC_Dhc5s7woww",
#         "title": "How to learn Python programming | Guido van Rossum and Lex Fridman",
#         "description": "Lex Fridman Podcast full episode: https://www.youtube.com/watch?v=-DVyjdw4t9I\nPlease support this podcast by checking out our sponsors:\n- GiveDirectly: https://givedirectly.org/lex to get gift matched up to $1000\n- Eight Sleep: https://www.eightsleep.com/lex to get special savings\n- Fundrise: https://fundrise.com/lex\n- InsideTracker: https://insidetracker.com/lex to get 20% off\n- Athletic Greens: https://athleticgreens.com/lex to get 1 month of fish oil\n\nGUEST BIO:\nGuido van Rossum is the creator of Python programming language.\n\nPODCAST INFO:\nPodcast website: https://lexfridman.com/podcast\nApple Podcasts: https://apple.co/2lwqZIr\nSpotify: https://spoti.fi/2nEwCF8\nRSS: https://lexfridman.com/feed/podcast/\nFull episodes playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOdP_8GztsuKi9nrraNbKKp4\nClips playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOeciFP3CBCIEElOJeitOr41\n\nSOCIAL:\n- Twitter: https://twitter.com/lexfridman\n- LinkedIn: https://www.linkedin.com/in/lexfridman\n- Facebook: https://www.facebook.com/lexfridman\n- Instagram: https://www.instagram.com/lexfridman\n- Medium: https://medium.com/@lexfridman\n- Reddit: https://reddit.com/r/lexfridman\n- Support on Patreon: https://www.patreon.com/lexfridman",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/F2Mx-u7auUs/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Lex Clips",
#         "tags": [
#           "ai",
#           "ai clips",
#           "ai podcast",
#           "ai podcast clips",
#           "artificial intelligence",
#           "artificial intelligence podcast",
#           "computer science",
#           "consciousness",
#           "deep learning",
#           "einstein",
#           "elon musk",
#           "engineering",
#           "friedman",
#           "guido van rossum",
#           "joe rogan",
#           "lex ai",
#           "lex clips",
#           "lex fridman",
#           "lex fridman podcast",
#           "lex friedman",
#           "lex mit",
#           "lex podcast",
#           "machine learning",
#           "math",
#           "math podcast",
#           "mathematics",
#           "mit ai",
#           "philosophy",
#           "physics",
#           "physics podcast",
#           "science",
#           "tech",
#           "tech podcast",
#           "technology",
#           "turing"
#         ],
#         "categoryId": "28",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "How to learn Python programming | Guido van Rossum and Lex Fridman",
#           "description": "Lex Fridman Podcast full episode: https://www.youtube.com/watch?v=-DVyjdw4t9I\nPlease support this podcast by checking out our sponsors:\n- GiveDirectly: https://givedirectly.org/lex to get gift matched up to $1000\n- Eight Sleep: https://www.eightsleep.com/lex to get special savings\n- Fundrise: https://fundrise.com/lex\n- InsideTracker: https://insidetracker.com/lex to get 20% off\n- Athletic Greens: https://athleticgreens.com/lex to get 1 month of fish oil\n\nGUEST BIO:\nGuido van Rossum is the creator of Python programming language.\n\nPODCAST INFO:\nPodcast website: https://lexfridman.com/podcast\nApple Podcasts: https://apple.co/2lwqZIr\nSpotify: https://spoti.fi/2nEwCF8\nRSS: https://lexfridman.com/feed/podcast/\nFull episodes playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOdP_8GztsuKi9nrraNbKKp4\nClips playlist: https://www.youtube.com/playlist?list=PLrAXtmErZgOeciFP3CBCIEElOJeitOr41\n\nSOCIAL:\n- Twitter: https://twitter.com/lexfridman\n- LinkedIn: https://www.linkedin.com/in/lexfridman\n- Facebook: https://www.facebook.com/lexfridman\n- Instagram: https://www.instagram.com/lexfridman\n- Medium: https://medium.com/@lexfridman\n- Reddit: https://reddit.com/r/lexfridman\n- Support on Patreon: https://www.patreon.com/lexfridman"
#         },
#         "defaultAudioLanguage": "en-US"
#       },
#       "contentDetails": {
#         "duration": "PT7M7S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "588036",
#         "likeCount": "15955",
#         "favoriteCount": "0",
#         "commentCount": "351"
#       }
#     },
#     {
#       "kind": "youtube#video",
#       "etag": "Be73-AXStCuzLY9u28XaxwlNd-Q",
#       "id": "nluUYtejoIE",
#       "snippet": {
#         "publishedAt": "2024-06-21T07:55:33Z",
#         "channelId": "UCAy1PN6jrZXrGFg79WP_91A",
#         "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#         "description": "In this quick tutorial, I\u2019ll show you how to write your very first line of Python code: the classic \"Hello, World!\" \ud83c\udf0d\u2728\n\nWhether you're a total beginner or brushing up on your basics, this video will get you started in under a minute. \ud83d\ude80\n\n\n\nDon't forget to like, subscribe, and leave a comment on what you want to learn next! \ud83d\udd25\n\nJoin me in the PROGRAMMER'S REALM!\n\n#Python #Programming #HelloWorld #PythonTutorial #LearnToCode #CodingForBeginners #TheProgrammersRealm",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/nluUYtejoIE/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "The Programmers Realm",
#         "tags": [
#           "python",
#           "programming",
#           "helloworld",
#           "pythontutorial",
#           "learntocode",
#           "codingforbeginners",
#           "theprogrammersrealm"
#         ],
#         "categoryId": "28",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "en",
#         "localized": {
#           "title": "Python Basics: Your FIRST Program in Under a Minute! \ud83d\ude80",
#           "description": "In this quick tutorial, I\u2019ll show you how to write your very first line of Python code: the classic \"Hello, World!\" \ud83c\udf0d\u2728\n\nWhether you're a total beginner or brushing up on your basics, this video will get you started in under a minute. \ud83d\ude80\n\n\n\nDon't forget to like, subscribe, and leave a comment on what you want to learn next! \ud83d\udd25\n\nJoin me in the PROGRAMMER'S REALM!\n\n#Python #Programming #HelloWorld #PythonTutorial #LearnToCode #CodingForBeginners #TheProgrammersRealm"
#         },
#         "defaultAudioLanguage": "en"
#       },
#       "contentDetails": {
#         "duration": "PT25S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "true",
#         "licensedContent": false,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "1444010",
#         "likeCount": "19086",
#         "favoriteCount": "0",
#         "commentCount": "152"
#       }
#     }
#   ],
#   "pageInfo": {
#     "totalResults": 5,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# **Channels API ENDPOINT**

# %%
CHANNELS_URL = "https://www.googleapis.com/youtube/v3/channels"

# %%
channel_ids = []

for item in video_data["items"]:
    channel_ids.append(item["snippet"]["channelId"])

print(channel_ids)
# Out:
# ['UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCWv7vMbMWH4-V0ZXdmDpPBA', 'UC7zZ2-Q_oxbUaoMVL0z51wg', 'UCJIfeSCssxSC_Dhc5s7woww', 'UCAy1PN6jrZXrGFg79WP_91A']

# %%
channel_ids = list(set(channel_ids))

print(channel_ids)
# Out:
# ['UCWv7vMbMWH4-V0ZXdmDpPBA', 'UCJIfeSCssxSC_Dhc5s7woww', 'UC7zZ2-Q_oxbUaoMVL0z51wg', 'UCAy1PN6jrZXrGFg79WP_91A']

# %%
channel_ids = ",".join(channel_ids)

print(channel_ids)
# Out:
# UCWv7vMbMWH4-V0ZXdmDpPBA,UCWv7vMbMWH4-V0ZXdmDpPBA,UC7zZ2-Q_oxbUaoMVL0z51wg,UCJIfeSCssxSC_Dhc5s7woww,UCAy1PN6jrZXrGFg79WP_91A

# %%
channel_params = {
    "part": "snippet,statistics",
    "id": channel_ids,
    "key": "AIzaSyDU4h1lYF42-xRyXdAs7e9PH8re09mICm8"
}

# %%
channel_response = requests.get(CHANNELS_URL, params=channel_params)
print(channel_response.status_code)
# Out:
# 200

# %%
channel_data = channel_response.json()

# %%
print(json.dumps(channel_data, indent = 2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "Sq2bcSGvT3YELoz6dAlkwgpXhOE",
#   "pageInfo": {
#     "totalResults": 4,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#channel",
#       "etag": "sddVt72LgPq_a5JIEdn2rmVKMg8",
#       "id": "UCJIfeSCssxSC_Dhc5s7woww",
#       "snippet": {
#         "title": "Lex Clips",
#         "description": "Clips from the Lex Fridman podcast. Visit the main channel for full conversations and other videos.",
#         "customUrl": "@lexclips",
#         "publishedAt": "2019-08-06T22:07:58Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_mqpG4xlDaXgYX1s4p2YLKke5KfakvFRmhPNXqT1VdpHaM=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_mqpG4xlDaXgYX1s4p2YLKke5KfakvFRmhPNXqT1VdpHaM=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_mqpG4xlDaXgYX1s4p2YLKke5KfakvFRmhPNXqT1VdpHaM=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Lex Clips",
#           "description": "Clips from the Lex Fridman podcast. Visit the main channel for full conversations and other videos."
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "608761697",
#         "subscriberCount": "1630000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "9134"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "ndzjw7-Yn64gRRNWK0meKFXzbbk",
#       "id": "UCWv7vMbMWH4-V0ZXdmDpPBA",
#       "snippet": {
#         "title": "Programming with Mosh",
#         "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n",
#         "customUrl": "@programmingwithmosh",
#         "publishedAt": "2014-10-07T00:40:53Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/HCv0fXFEEcD0HRyF0_qR1K7b7qO3KCzmIoyH1DEJYB94CIUFhIE5i2t2IDIPX97W1-DK4hegww=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Programming with Mosh",
#           "description": "Hi! I'm Mosh \ud83d\udc4b, a software engineer with over 20 years of experience.  I'm all about clear, concise, practical coding tutorials \u2013 no fluff, just the good stuff! My courses focus on real-world projects and the skills that will get you hired. I've helped millions of students transform their careers. \n\nWant to level up your skills? Subscribe and hit the bell to get notified when I upload new videos!\n\nFor sponsorships: partners@codewithmosh.com\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "275288811",
#         "subscriberCount": "5110000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "246"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "znQUawl2bkjRmb3BCYsVitLNVG0",
#       "id": "UC7zZ2-Q_oxbUaoMVL0z51wg",
#       "snippet": {
#         "title": "Sajjaad Khader",
#         "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n",
#         "customUrl": "@sajjaadkhader",
#         "publishedAt": "2020-06-18T00:50:20.154391Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/cs-8bhqefhiquqoe94NFueqi3z1t4Yrm_sQN09wbKi1fRwWX7GWAi4lfH0QU2bDGomYVsBXp=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "Sajjaad Khader",
#           "description": "Teaching you how to break into tech in 2026. \n\n\ud83d\udc4b Hi! I'm Sajjaad, a 24 year old big tech software engineer (ex-Amazon). \n\ud83c\udf93 I graduated with a masters degree from Georgia Tech in computer science at 20. \n\nThrough sharing my own academic/career experiences, exploring useful tools, and interviewing successful people in tech, I hope to inspire a new generation of folks interested in tech and demystify the process when it comes to education and finding great jobs with great pay!\n\n\u2764\ufe0f My Other Socials\n\ud83d\udcf8Instagram: @sajjaad.khader - 465k Followers\n\ud83d\udcf1TikTok: @sajjaadkhader - 185k Followers\n\ud83d\udc4dLinkedIn: sajjaad-khader - 45k Followers\n\n\ud83d\udd3d Check out my free resume template!\nhttps://sajjaad-s-site.thinkific.com/courses/land-tech-job\n"
#         },
#         "country": "US"
#       },
#       "statistics": {
#         "viewCount": "61170216",
#         "subscriberCount": "323000",
#         "hiddenSubscriberCount": false,
#         "videoCount": "1320"
#       }
#     },
#     {
#       "kind": "youtube#channel",
#       "etag": "c8X5nNN3rOdQidw72auM6bOnP2I",
#       "id": "UCAy1PN6jrZXrGFg79WP_91A",
#       "snippet": {
#         "title": "The Programmers Realm",
#         "description": "Welcome to The Programmers Realm! \ud83d\ude80\n\nDive into the world of coding and technology with me, where we explore the essentials of Python programming, web development, networking and anything computers! Whether you're a beginner taking your first steps or an advanced programmer looking to refine your skills, we've got something for everyone \u2728\n\nWhat's your coding goal? Share your thoughts and projects in the comments, and let's build the future together! \ud83c\udf10\ud83d\udcbb\n\n#Python #Programming #WebDevelopment #Networking #LearnToCode #TheProgrammersRealm #CodingForBeginners #WebDevelopment #Code #vscode #javascript #networking #network  #webdevelopment #webseries \n\nA \"TFR\" brand.\n",
#         "customUrl": "@programmersrealm",
#         "publishedAt": "2023-07-06T06:35:12.290436Z",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s88-c-k-c0x00ffffff-no-rj",
#             "width": 88,
#             "height": 88
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s240-c-k-c0x00ffffff-no-rj",
#             "width": 240,
#             "height": 240
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/qx-Qdoznh3EQ2ovIYY41fp2cmdKWIHXN0iNjcVxlqLmmkZ4Up50k9n44o_ay4CtNB8uw6JrimQ=s800-c-k-c0x00ffffff-no-rj",
#             "width": 800,
#             "height": 800
#           }
#         },
#         "localized": {
#           "title": "The Programmers Realm",
#           "description": "Welcome to The Programmers Realm! \ud83d\ude80\n\nDive into the world of coding and technology with me, where we explore the essentials of Python programming, web development, networking and anything computers! Whether you're a beginner taking your first steps or an advanced programmer looking to refine your skills, we've got something for everyone \u2728\n\nWhat's your coding goal? Share your thoughts and projects in the comments, and let's build the future together! \ud83c\udf10\ud83d\udcbb\n\n#Python #Programming #WebDevelopment #Networking #LearnToCode #TheProgrammersRealm #CodingForBeginners #WebDevelopment #Code #vscode #javascript #networking #network  #webdevelopment #webseries \n\nA \"TFR\" brand.\n"
#         },
#         "country": "AU"
#       },
#       "statistics": {
#         "viewCount": "2184996",
#         "subscriberCount": "7310",
#         "hiddenSubscriberCount": false,
#         "videoCount": "23"
#       }
#     }
#   ]
# }
